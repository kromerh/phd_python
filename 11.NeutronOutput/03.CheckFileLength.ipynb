# %% [markdown]
# 2018-10-17 and 2018-6-29 have different lengths?

# %%
import pandas as pd
import os

path = '/Users/hkromer/02_PhD/tmp/data_robert/'
fnames = ['2018-10-17', '2018-6-29', '2018-7-11']

files = os.listdir(path)
files = [f for f in files if f.endswith('.csv')]

# %%
data = pd.DataFrame()
num_entries = []
for f in files:
    _ = pd.read_csv(f'{path}{f}', index_col=0)
    print(_.head())
    num_entries.append(_.shape[0])
    
data['filename'] = files
data['entries'] = num_entries
data['entries'].value_counts()

# %%
data_wrong_lines = data[ data['entries'] == 8640]
data_wrong_lines
# Out:
#            filename  entries
# 20   2018-10-17.csv     8640
# 119   2018-6-29.csv     8640

# %%
data = pd.read_csv(f'{path}2019-4-30.csv', index_col=0)
data.index = pd.to_datetime(data.index, format='%Y-%m-%d %H:%M:%S')
data.shape
# Out:
# (8635, 4)

# %%
correct_range = pd.date_range(start='2019-4-30 00:00:00', end='2019-4-30 23:59:59', freq='10s')

# %%
correct_range.shape
# Out:
# (8640,)

# %%
l1 = data.index.strftime('%Y-%m-%d %H:%M:%S').tolist()
l2 = correct_range.strftime('%Y-%m-%d %H:%M:%S').tolist()

# %%
for item in l2:
    if item in l1:
        pass
    else:
        print(f'Missing time in the original data: {item}')
# Out:
# Missing time in the original data: 2019-04-30 23:59:10
# Missing time in the original data: 2019-04-30 23:59:20
# Missing time in the original data: 2019-04-30 23:59:30
# Missing time in the original data: 2019-04-30 23:59:40
# Missing time in the original data: 2019-04-30 23:59:50

# %%
data.tail()
# Out:
#                      HV_voltage  HV_current  dose_corrected  neutron_output
# time
# 2019-04-30 23:58:20         0.0         0.0             0.0             0.0
# 2019-04-30 23:58:30         0.0         0.0             0.0             0.0
# 2019-04-30 23:58:40         0.0         0.0             0.0             0.0
# 2019-04-30 23:58:50         0.0         0.0             0.0             0.0
# 2019-04-30 23:59:00         0.0         0.0             0.0             0.0

# %%
data.duplicated(subset='time')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8635    False
# 8636    False
# 8637    False
# 8638    False
# 8639    False
# Length: 8640, dtype: bool

# %%
data
# Out:
#                     time  HV_voltage  HV_current  dose_corrected  \
# 0    2018-10-17 00:00:00         0.0         0.0        0.000000
# 1    2018-10-17 00:00:10         0.0         0.0        0.000000
# 2    2018-10-17 00:00:20         0.0         0.0        0.000000
# 3    2018-10-17 00:00:30         0.0         0.0        0.000000
# 4    2018-10-17 00:00:40         0.0         0.0        0.000000
# ...                  ...         ...         ...             ...
# 8635 2018-10-17 23:59:10         0.0         0.0       19.573010
# 8636 2018-10-17 23:59:20         0.0         0.0       24.366400
# 8637 2018-10-17 23:59:30         0.0         0.0       21.969705
# 8638 2018-10-17 23:59:40         0.0         0.0       24.366400
# 8639 2018-10-17 23:59:50         0.0         0.0       21.969705
#
#       neutron_output
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ...              ...
# 8635   465052.736097
# ...
