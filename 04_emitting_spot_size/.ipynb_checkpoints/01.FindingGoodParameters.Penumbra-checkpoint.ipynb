# %% [markdown]
# # Emitting Spot Size simulations - investigate the penumbra, the effect of the thickness of the detector on the seen FWHM

# %%
import pandas as pd
import numpy as np
import os, sys, glob
import re
from scipy.interpolate import interp1d
# import matplotlib
from matplotlib import pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import scipy
from scipy import stats
from scipy.stats import poisson
from scipy import optimize
from scipy.misc import derivative
import itertools



# workflow:
# 	1. import the results (edge position vs countrate in the detector)
#	2. fit logistic fermi function to the ESF --> obtain FWHM as p[2]*3.53
#	3. select +/- 1 FWHM plus 3 points of this fermi function and interpolate the fitted function
#	4. select 30 measurement points along that fitted function (use interpolation)
#	5. sample from poisson 1000 points for each of these positions (this means from the fitted data!)
#	6. analog to 2, re-compute logistic fermi function to ESF --> obtain 1000 FWHMs as p[2]*3.53 
#	7. least squares linear regression for y = diameter in MCNP, x = FWHM from the fit to the ESF. 
#      Then find uncertainty for each FWHM point x, translated to an uncertainty in y

master_folder = '/Users/hkromer/02_PhD/02_Data/09.NeutronEmittingSpot/01.FindingGoodParameters/'
S0 = 3e7  # total neutron yield 3*10**7 neutrons/s

deutEnergy = 100
emission_angle = 2
# ----------------------------------------------------------------------------------------------------
# 	1. import the results (edge position vs countrate in the detector). convert units to mm, load cross sections and compute countrate
# ----------------------------------------------------------------------------------------------------

fname = '/Users/hkromer/02_PhD/02_Data/09.NeutronEmittingSpot/01.FindingGoodParameters/df_results_penumbra.csv'
df_MCNP_results = pd.read_csv(fname, index_col=0)

df_MCNP_results['diameter'] = np.multiply(np.multiply(df_MCNP_results['radius'], 2), 10)  # diameter of the MCNP source in mm

df_MCNP_results['x_pos'] = df_MCNP_results['x_pos']*10.0  # convert to mm!

# %%
df_MCNP_results.head()
# Out:
#    case  radius  x_pos               run       nps  entering_tracks  \
# 0     1    0.05  -5.60  rad0.050_x-0.560  100000.0             2720
# 1     1    0.05  -5.45  rad0.050_x-0.545  100000.0             2720
# 2     1    0.05  -5.30  rad0.050_x-0.530  100000.0             2720
# 3     1    0.05  -5.15  rad0.050_x-0.515  100000.0             2720
# 4     1    0.05  -4.99  rad0.050_x-0.499  100000.0             2720
#
#    population    F4_tot     R_tot         f           C    C_cutoff  diameter
# 0        2720  0.654886  0.001637  0.008481  416.496996  312.372747       1.0
# 1        2720  0.654886  0.001637  0.008481  416.496996  312.372747       1.0
# 2        2720  0.654886  0.001637  0.008481  416.496996  312.372747       1.0
# 3        2720  0.654886  0.001637  0.008481  416.496996  312.372747       1.0
# 4        2720  0.654886  0.001637  0.008481  416.496996  312.372747       1.0

# %%
# ----------------------------------------------------------------------------------------------------
# 	2. fit logistic fermi function to the ESF --> obtain FWHM as p[2]*3.53
# ----------------------------------------------------------------------------------------------------

def fun_calculate_FWHM_of_ESF(
	# calculate the FWHM of the LSF fitted to the ESF
	# return FWHM, Y_log_fermi_func, p1, r_squared
	X,  # X values from the ESF (in mm) 
	Y,  # Y values from the ESF (can be anything)
	p0 # initial guess for the fit
	):

	# log_fermi_func_zboray
	def fitfunc(p, x):
		z = np.exp( -( (x-p[1])/(p[2]) ) )
		return (p[0] / ( 1 + z )) + p[3]
	def errfunc(p, x, y):
		return fitfunc(p, x) - y # Distance to the fit function


	# m = np.mean(Y[0:5])
	# p0 = [5e+03, 5e-2, radius, m] # Initial guess for the parameters
	p1, success = optimize.leastsq(errfunc, p0[:], args=(X, Y))

	# r-squared
	residuals = Y - fitfunc(p1, X)
	ss_residuals = np.sum(residuals**2)   # residual sum of squares
	ss_tot =  np.sum((Y-np.mean(Y))**2) # total sum of squares
	r_squared = 1 - (ss_residuals / ss_tot)
	FWHM = 3.53*p1[2]
	
	Y_log_fermi_func = fitfunc(p1, X)
	
	# return the FWHM from the 3.53c (logistic fit) and 
	# Y_log_fermi_func: is the Y values for the plot of the log fermi function
	
	return FWHM, Y_log_fermi_func, p1, r_squared

def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return idx

def fit_FWHM(df,Y_colname):
	# returns the FWHM for a given X, Y
	# X is the edge position
	# Y is the countrate or the counts in the detector

	case = df['case'].unique()[0]
	diameter = df['diameter'].unique()[0]
	# if (case == 148) & (diameter == 1.0):  # do only one diameter
	if case > -1:  # always valid
			
		
		

		print('Processing case {}, diameter {} mm.'.format(case, diameter))

		X = df['x_pos'].values
		Y = df[Y_colname].values


		# find the optimal p0 as initial guess for the fit, then use that to return the FWHM
		# m = np.mean(Y[0:5])
		# m = [1e1, 1e2, 1e3, 1e4, 1e5, 1e6]
		# print(np.max(Y))
		m = [1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10, np.max(Y)]
		a = [1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8]
		b = [1e-3, 1e-2, 2e-2, 3e-2, 4e-2, 5e-2]
		c = [0.5, 2, 4, 6, 8, 10, 15, 20, 30]
		for kk in list(itertools.product(a,b,c,m)):
			
		# for kk in list(itertools.product(a,b,c)):
			p0 = [-kk[0], kk[1], kk[2]/3.53, kk[3]] # Initial guess for the parameters	
			FWHM_0, Y_log_fermi_func_0, p1_0, r_squared_0 = fun_calculate_FWHM_of_ESF(X, Y, p0)
			FWHM_0 = np.abs(FWHM_0)
			diff_fit =np.abs(Y_log_fermi_func_0[0]-Y_log_fermi_func_0[-1])
			diff_Y = np.abs(Y[0]-Y[-1])
			if (np.abs(FWHM_0) > 1e-1) & (np.abs(FWHM_0) < 2*diameter) & (np.divide(np.abs(diff_fit-diff_Y), diff_Y) < 0.5 ):  # computed FWHM larger than 0
			# if (np.abs(FWHM_0) > 1) & (np.abs(FWHM_0) < 50):  # computed FWHM larger than 0

				print(p1_0)
				break

		# print((Y_log_fermi_func_0[0] < Y_log_fermi_func_0[-1]))
		if FWHM_0 > 100:
			print('FWHM {} LARGER THAN 100! Exit.'.format(FWHM_0))
			sys.exit()
		print('FWHM_0: {} '.format(FWHM_0))
		print('p1_0: {}'.format(p1_0))

		# fig, ax = plt.subplots(1)	
		# ax.plot(X, Y_log_fermi_func_0, color='darkblue', label='ESF fit')
		
		# ax.scatter(X, Y, edgecolor='darkorange', label='MCNP data', color='darkorange')
		# # print(X,Y)
		# # ax.scatter([X[idx_X_neg],X[idx_X_pos]], [Y[idx_X_neg],Y[idx_X_pos]], edgecolor='red', color='red', marker='x', s=120)
			
		# 	# FWHM, Y_log_fermi_func, p1, r_squared = compute_FWHM(X, df_poisson.iloc[:,ii].values,rad)
			
		# ax.tick_params('x', colors='black', labelsize=12)	
		# ax.tick_params('y', colors='black', labelsize=12)	
		# # grid
		# ax.grid(b=True, which='major', linestyle='-')#, color='gray')
		# ax.grid(b=True, which='minor', linestyle='--')#, color='gray')
		# plt.title('Case: {:.0f}, Diameter: {:.2f} mm'.format(case, diameter))
		# plt.legend(loc='best')
		# plt.xlabel('Edge position [mm]')
		# plt.ylabel('Countrate for tot. Neutron Yield: {:.1e} n/s'.format(S0))
		# plt.tight_layout()
		# plt.show()
		
		
		

		###################################################
		# fit again with 0 +/- 1 FWHM and three points more!
		###################################################
		
		idx_X_pos = find_nearest(X,FWHM_0)
		print(FWHM_0, X[idx_X_pos-1], X[idx_X_pos], X[idx_X_pos+1])

		idx_X_neg = find_nearest(X,-FWHM_0)
		# print(-FWHM, X[idx_X_neg-1], X[idx_X_neg], X[idx_X_neg+1])
		# plt.scatter(X,Y,color='blue')
		# plt.scatter(X[idx_X_pos], Y[idx_X_pos], color='red')
		# plt.scatter(X[idx_X_neg], Y[idx_X_neg], color='green')
		# plt.show()
		offset_points = 3
		X = X[idx_X_neg-offset_points:idx_X_pos+offset_points]
		Y = Y[idx_X_neg-offset_points:idx_X_pos+offset_points]
		print(idx_X_neg, idx_X_pos)
		

		FWHM, Y_log_fermi_func, p1, r_squared = fun_calculate_FWHM_of_ESF(X, Y, p1_0)
		# print(p1)
		# a = [-1e6, -1e5, -1e4, -1e3, -1e2, -1e1,-1e-1, -1e-2, -1e-3, -1e-4, 0, 1, 1e-1, 1e-2, 1e-3, 1e-4, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6]
		# b = [-1e6, -1e5, -1e4, -1e3, -1e2, -1e1,-1e-1, -1e-2, -1e-3, -1e-4, 0, 1, 1e-1, 1e-2, 1e-3, 1e-4, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6]
		# c = [-1e6, -1e5, -1e4, -1e3, -1e2, -1e1,-1e-1, -1e-2, -1e-3, -1e-4, 0, 1, 1e-1, 1e-2, 1e-3, 1e-4, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6]
		# d = [-1e6, -1e5, -1e4, -1e3, -1e2, -1e1,-1e-1, -1e-2, -1e-3, -1e-4, 0, 1, 1e-1, 1e-2, 1e-3, 1e-4, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6]
	 
		# for kk in list(itertools.product(a,b,c,d)):
			# p0 = [kk[0], kk[1], kk[2], kk[3]] # Initial guess for the parameters			
			# FWHM, Y_log_fermi_func, p1, r_squared = fun_calculate_FWHM_of_ESF(X, Y, p1_0)
					
			# if (p1[1] > 1e-3) & (p1[1] < 100):  # computed FWHM larger than 0
				# print(p1)
				# break


		print('Plotting fit to ESF for case {}, diameter {} mm.'.format(case, diameter))


		fig, ax = plt.subplots(1)	
		ax.plot(X, Y_log_fermi_func, color='darkblue', label='ESF fit')
		
		ax.scatter(X, Y, edgecolor='darkorange', label='MCNP data', color='darkorange')
		# print(X,Y)
		# ax.scatter([X[idx_X_neg],X[idx_X_pos]], [Y[idx_X_neg],Y[idx_X_pos]], edgecolor='red', color='red', marker='x', s=120)
			
			# FWHM, Y_log_fermi_func, p1, r_squared = compute_FWHM(X, df_poisson.iloc[:,ii].values,rad)
			
		ax.tick_params('x', colors='black', labelsize=12)	
		ax.tick_params('y', colors='black', labelsize=12)	
		# grid
		ax.grid(b=True, which='major', linestyle='-')#, color='gray')
		ax.grid(b=True, which='minor', linestyle='--')#, color='gray')
		plt.title('Case: {:.0f}, Diameter: {:.2f} mm'.format(case, diameter))
		plt.legend(loc='best')
		plt.xlabel('Edge position [mm]')
		plt.ylabel('Countrate for tot. Neutron Yield: {:.1e} n/s'.format(S0))
		plt.tight_layout()
		# plt.show()
		plt.savefig('{}ESF_fit_plots/diameter_{:.2f}_mm_case_{:.0f}_ESF_fit.png'.format(master_folder, diameter, case), dpi=100)
		plt.clf()
		plt.close('all')


		# print into file! 
		fname = '{}ESF_fit_csv/case_{}_diameter_{}_mm_ESF_fit.csv'.format(master_folder,case,diameter)
		this_df = pd.DataFrame()
		this_df['x_pos_mm'] = X
		this_df[Y_colname] = Y
		this_df['Y_log_fermi_func'] = Y_log_fermi_func
		this_df.to_csv(fname)

		return pd.Series(p1_0)
		# FWHM: 3.53*c of fitted LSF
		# X: edge positions for the fitted Y_log_fermi_function
		# Y_log_fermi_func values of the fitted function
		# p1: fitted parameters
		# r_squared: 1-(residual sum of squares / total sum of squares)

Y_colname = 'C_cutoff'
df_MCNP_results.groupby(['case', 'diameter']).apply(lambda x: fit_FWHM(x,Y_colname)).reset_index()

# sys.exit()
# Out:
# Processing case 1, diameter 1.0 mm.
# [1.30866167e+01 7.35812114e-02 1.46672178e-01 3.12371161e+02]
# FWHM_0: 0.5177527874241662
# p1_0: [1.30866167e+01 7.35812114e-02 1.46672178e-01 3.12371161e+02]
# 0.5177527874241662 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 1, diameter 1.0 mm.
# Processing case 1, diameter 10.0 mm.
# [-1.42610706e+01  6.03487225e-02 -9.00269615e-01  3.00827549e+02]
# FWHM_0: 3.1779517425085504
# p1_0: [-1.42610706e+01  6.03487225e-02 -9.00269615e-01  3.00827549e+02]
# 3.1779517425085504 2.84 3.12 3.41
# 26 48
# Plotting fit to ESF for case 1, diameter 10.0 mm.
# Processing case 2, diameter 1.0 mm.
# [3.36092232e+01 2.02941095e-02 1.65473016e-01 2.91872833e+02]
# FWHM_0: 0.5841197449029979
# p1_0: [3.36092232e+01 2.02941095e-02 1.65473016e-01 2.91872833e+02]
# 0.5841197449029979 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 2, diameter 1.0 mm.
# Processing case 2, diameter 10.0 mm.
# [-3.38239042e+01  8.26888647e-02 -9.41352336e-01  3.00971430e+02]
# FWHM_0: 3.3229737445884586
# p1_0: [-3.38239042e+01  8.26888647e-02 -9.41352336e-01  3.00971430e+02]
# 3.3229737445884586 3.12 3.41 3.69
# 25 49
# Plotting fit to ESF for case 2, diameter 10.0 mm.
# Processing case 3, diameter 1.0 mm.
# [-6.63540156e+01  1.65922232e-02 -1.62968272e-01  3.25490270e+02]
# FWHM_0: 0.5752779997507267
# p1_0: [-6.63540156e+01  1.65922232e-02 -1.62968272e-01  3.25490270e+02]
# 0.5752779997507267 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 3, diameter 1.0 mm.
# Processing case 3, diameter 10.0 mm.
# [-6.06832292e+01  5.60606707e-02 -9.11590717e-01  3.01107695e+02]
# FWHM_0: 3.2179152318658657
# p1_0: [-6.06832292e+01  5.60606707e-02 -9.11590717e-01  3.01107695e+02]
# 3.2179152318658657 2.84 3.12 3.41
# 26 48
# Plotting fit to ESF for case 3, diameter 10.0 mm.
# Processing case 4, diameter 1.0 mm.
# [ 4.75527182  0.10040307  0.15896644 80.242525  ]
# FWHM_0: 0.5611515307960605
# p1_0: [ 4.75527182  0.10040307  0.15896644 80.242525  ]
# 0.5611515307960605 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 4, diameter 1.0 mm.
# Processing case 4, diameter 10.0 mm.
# [3.63676159e+00 3.46161946e-03 1.20343507e+00 7.30910334e+01]
# FWHM_0: 4.248125810160562
# p1_0: [3.63676159e+00 3.46161946e-03 1.20343507e+00 7.30910334e+01]
# 4.248125810160562 3.97 4.26 4.54
# 22 52
# Plotting fit to ESF for case 4, diameter 10.0 mm.
# Processing case 5, diameter 1.0 mm.
# [1.02121628e+01 2.78562091e-02 1.49847322e-01 7.47873961e+01]
# FWHM_0: 0.5289610464507044
# p1_0: [1.02121628e+01 2.78562091e-02 1.49847322e-01 7.47873961e+01]
# 0.5289610464507044 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 5, diameter 1.0 mm.
# Processing case 5, diameter 10.0 mm.
# [ 7.45296976 -0.11088578  1.18999565 69.32360386]
# FWHM_0: 4.200684661054539
# p1_0: [ 7.45296976 -0.11088578  1.18999565 69.32360386]
# 4.200684661054539 3.97 4.26 4.54
# 22 52
# Plotting fit to ESF for case 5, diameter 10.0 mm.
# Processing case 6, diameter 1.0 mm.
# [1.91242000e+01 1.20838282e-02 1.43279148e-01 6.58833275e+01]
# FWHM_0: 0.5057753926152431
# p1_0: [1.91242000e+01 1.20838282e-02 1.43279148e-01 6.58833275e+01]
# 0.5057753926152431 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 6, diameter 1.0 mm.
# Processing case 6, diameter 10.0 mm.
# [-16.72900956  -0.11633253  -1.29173469  76.90046193]
# FWHM_0: 4.559823440585189
# p1_0: [-16.72900956  -0.11633253  -1.29173469  76.90046193]
# 4.559823440585189 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 6, diameter 10.0 mm.
# Processing case 7, diameter 1.0 mm.
# [ 2.01819816  0.11992075  0.12868996 46.21420854]
# FWHM_0: 0.4542755542643399
# p1_0: [ 2.01819816  0.11992075  0.12868996 46.21420854]
# 0.4542755542643399 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 7, diameter 1.0 mm.
# Processing case 7, diameter 10.0 mm.
# [ 2.09958286  0.89400817  1.28125376 42.71991502]
# FWHM_0: 4.522825771189363
# p1_0: [ 2.09958286  0.89400817  1.28125376 42.71991502]
# 4.522825771189363 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 7, diameter 10.0 mm.
# Processing case 8, diameter 1.0 mm.
# [5.26719845e+00 5.68384441e-03 1.36856485e-01 4.29659398e+01]
# FWHM_0: 0.483103390973216
# p1_0: [5.26719845e+00 5.68384441e-03 1.36856485e-01 4.29659398e+01]
# 0.483103390973216 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 8, diameter 1.0 mm.
# Processing case 8, diameter 10.0 mm.
# [ 5.03250622  0.61846593  1.38771765 39.85065609]
# FWHM_0: 4.898643290229066
# p1_0: [ 5.03250622  0.61846593  1.38771765 39.85065609]
# 4.898643290229066 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 8, diameter 10.0 mm.
# Processing case 9, diameter 1.0 mm.
# [ 1.03621957e+01 -1.77956778e-03  1.40926348e-01  3.78743626e+01]
# FWHM_0: 0.497470008094279
# p1_0: [ 1.03621957e+01 -1.77956778e-03  1.40926348e-01  3.78743626e+01]
# 0.497470008094279 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 9, diameter 1.0 mm.
# Processing case 9, diameter 10.0 mm.
# [1.01928828e+01 3.37717484e-02 1.41095549e+00 3.47363735e+01]
# FWHM_0: 4.980672866482746
# p1_0: [1.01928828e+01 3.37717484e-02 1.41095549e+00 3.47363735e+01]
# 4.980672866482746 4.82 5.11 5.390000000000001
# 19 55
# Plotting fit to ESF for case 9, diameter 10.0 mm.
# Processing case 10, diameter 1.0 mm.
# [ 1.29167395e+02 -3.54978143e-03  4.69501704e-01  2.88127150e+03]
# FWHM_0: 1.6573410139091072
# p1_0: [ 1.29167395e+02 -3.54978143e-03  4.69501704e-01  2.88127150e+03]
# 1.6573410139091072 1.51 1.6600000000000001 1.8199999999999998
# 26 48
# Plotting fit to ESF for case 10, diameter 1.0 mm.
# Processing case 10, diameter 10.0 mm.
# [-9.99890398e+01  1.32038254e-01 -1.16207528e+00  2.25727292e+03]
# FWHM_0: 4.102125722853468
# p1_0: [-9.99890398e+01  1.32038254e-01 -1.16207528e+00  2.25727292e+03]
# 4.102125722853468 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 10, diameter 10.0 mm.
# Processing case 11, diameter 1.0 mm.
# [ 3.09358679e+02 -1.70032317e-02  4.94772736e-01  2.70220016e+03]
# FWHM_0: 1.7465477568559762
# p1_0: [ 3.09358679e+02 -1.70032317e-02  4.94772736e-01  2.70220016e+03]
# 1.7465477568559762 1.6600000000000001 1.8199999999999998 1.9700000000000002
# 25 49
# Plotting fit to ESF for case 11, diameter 1.0 mm.
# Processing case 11, diameter 10.0 mm.
# [-2.35409170e+02  9.45656217e-02 -1.10390740e+00  2.25817680e+03]
# FWHM_0: 3.896793128796549
# p1_0: [-2.35409170e+02  9.45656217e-02 -1.10390740e+00  2.25817680e+03]
# 3.896793128796549 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 11, diameter 10.0 mm.
# Processing case 12, diameter 1.0 mm.
# [ 6.09059867e+02 -1.60411708e-02  5.07324702e-01  2.40453141e+03]
# FWHM_0: 1.7908561997387296
# p1_0: [ 6.09059867e+02 -1.60411708e-02  5.07324702e-01  2.40453141e+03]
# 1.7908561997387296 1.6600000000000001 1.8199999999999998 1.9700000000000002
# 25 49
# Plotting fit to ESF for case 12, diameter 1.0 mm.
# Processing case 12, diameter 10.0 mm.
# [-4.54310227e+02  8.20936519e-02 -1.07251003e+00  2.25957130e+03]
# FWHM_0: 3.785960389967323
# p1_0: [-4.54310227e+02  8.20936519e-02 -1.07251003e+00  2.25957130e+03]
# 3.785960389967323 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 12, diameter 10.0 mm.
# Processing case 13, diameter 1.0 mm.
# [-3.19863209e+01  3.44109126e-02 -2.61815006e-01  7.48150950e+02]
# FWHM_0: 0.9242069695515376
# p1_0: [-3.19863209e+01  3.44109126e-02 -2.61815006e-01  7.48150950e+02]
# 0.9242069695515376 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 13, diameter 1.0 mm.
# Processing case 13, diameter 10.0 mm.
# [-4.09388406e+01 -1.23743905e-01 -1.33557944e+00  7.49402782e+02]
# FWHM_0: 4.714595406520511
# p1_0: [-4.09388406e+01 -1.23743905e-01 -1.33557944e+00  7.49402782e+02]
# 4.714595406520511 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 13, diameter 10.0 mm.
# Processing case 14, diameter 1.0 mm.
# [-7.59012432e+01 -1.08284455e-02 -2.64285041e-01  7.48243745e+02]
# FWHM_0: 0.9329261959440209
# p1_0: [-7.59012432e+01 -1.08284455e-02 -2.64285041e-01  7.48243745e+02]
# 0.9329261959440209 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 14, diameter 1.0 mm.
# Processing case 14, diameter 10.0 mm.
# [-8.30830986e+01 -1.16879400e-02 -1.26520690e+00  7.49806297e+02]
# FWHM_0: 4.4661803514029375
# p1_0: [-8.30830986e+01 -1.16879400e-02 -1.26520690e+00  7.49806297e+02]
# 4.4661803514029375 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 14, diameter 10.0 mm.
# Processing case 15, diameter 1.0 mm.
# [-1.51929895e+02  1.00766476e-02 -2.63589511e-01  7.48393748e+02]
# FWHM_0: 0.9304709725389592
# p1_0: [-1.51929895e+02  1.00766476e-02 -2.63589511e-01  7.48393748e+02]
# 0.9304709725389592 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 15, diameter 1.0 mm.
# Processing case 15, diameter 10.0 mm.
# [-1.61577726e+02  5.15876361e-02 -1.28735816e+00  7.50714673e+02]
# FWHM_0: 4.5443743212221115
# p1_0: [-1.61577726e+02  5.15876361e-02 -1.28735816e+00  7.50714673e+02]
# 4.5443743212221115 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 15, diameter 10.0 mm.
# Processing case 16, diameter 1.0 mm.
# [1.84197082e+01 3.37769008e-02 2.11251423e-01 4.07981512e+02]
# FWHM_0: 0.7457175217351483
# p1_0: [1.84197082e+01 3.37769008e-02 2.11251423e-01 4.07981512e+02]
# 0.7457175217351483 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 16, diameter 1.0 mm.
# Processing case 16, diameter 10.0 mm.
# [-2.45732572e+01  8.06387275e-02 -1.48169235e+00  4.32762212e+02]
# FWHM_0: 5.230374000999257
# p1_0: [-2.45732572e+01  8.06387275e-02 -1.48169235e+00  4.32762212e+02]
# 5.230374000999257 4.82 5.11 5.390000000000001
# 19 55
# Plotting fit to ESF for case 16, diameter 10.0 mm.
# Processing case 17, diameter 1.0 mm.
# [-4.39671741e+01  1.26945063e-03 -2.10540989e-01  4.26432247e+02]
# FWHM_0: 0.7432096899301915
# p1_0: [-4.39671741e+01  1.26945063e-03 -2.10540989e-01  4.26432247e+02]
# 0.7432096899301915 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 17, diameter 1.0 mm.
# Processing case 17, diameter 10.0 mm.
# [-4.93715401e+01  5.99443212e-02 -1.38899251e+00  4.33016055e+02]
# FWHM_0: 4.903143573209389
# p1_0: [-4.93715401e+01  5.99443212e-02 -1.38899251e+00  4.33016055e+02]
# 4.903143573209389 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 17, diameter 10.0 mm.
# Processing case 18, diameter 1.0 mm.
# [-8.75838498e+01  1.24944404e-03 -2.06004975e-01  4.26453153e+02]
# FWHM_0: 0.7271975625790255
# p1_0: [-8.75838498e+01  1.24944404e-03 -2.06004975e-01  4.26453153e+02]
# 0.7271975625790255 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 18, diameter 1.0 mm.
# Processing case 18, diameter 10.0 mm.
# [-9.39642979e+01  1.28720994e-01 -1.39550541e+00  4.33717068e+02]
# FWHM_0: 4.9261340799694375
# p1_0: [-9.39642979e+01  1.28720994e-01 -1.39550541e+00  4.33717068e+02]
# 4.9261340799694375 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 18, diameter 10.0 mm.
# Processing case 19, diameter 1.0 mm.
# [3.44343743e+01 4.47644733e-02 1.83264126e-01 8.25245146e+02]
# FWHM_0: 0.646922363503857
# p1_0: [3.44343743e+01 4.47644733e-02 1.83264126e-01 8.25245146e+02]
# 0.646922363503857 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 19, diameter 1.0 mm.
# Processing case 19, diameter 10.0 mm.
# [-3.25364097e+01  8.61226259e-03 -7.55947623e-01  8.00694238e+02]
# FWHM_0: 2.6684951095681964
# p1_0: [-3.25364097e+01  8.61226259e-03 -7.55947623e-01  8.00694238e+02]
# 2.6684951095681964 2.27 2.55 2.84
# 28 46
# Plotting fit to ESF for case 19, diameter 10.0 mm.
# Processing case 20, diameter 1.0 mm.
# [-8.80118646e+01  1.23543028e-02 -1.78581549e-01  8.59744493e+02]
# FWHM_0: 0.630392868181155
# p1_0: [-8.80118646e+01  1.23543028e-02 -1.78581549e-01  8.59744493e+02]
# 0.630392868181155 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 20, diameter 1.0 mm.
# Processing case 20, diameter 10.0 mm.
# [-8.54127503e+01  4.35361434e-02 -8.94985922e-01  8.01100126e+02]
# FWHM_0: 3.1593003034154736
# p1_0: [-8.54127503e+01  4.35361434e-02 -8.94985922e-01  8.01100126e+02]
# 3.1593003034154736 2.84 3.12 3.41
# 26 48
# Plotting fit to ESF for case 20, diameter 10.0 mm.
# Processing case 21, diameter 1.0 mm.
# [-1.75767848e+02  1.12945744e-02 -1.67671501e-01  8.59745120e+02]
# FWHM_0: 0.591880399790737
# p1_0: [-1.75767848e+02  1.12945744e-02 -1.67671501e-01  8.59745120e+02]
# 0.591880399790737 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 21, diameter 1.0 mm.
# Processing case 21, diameter 10.0 mm.
# [-1.57369656e+02  1.36822102e-02 -8.95997843e-01  8.01488939e+02]
# FWHM_0: 3.1628723856046346
# p1_0: [-1.57369656e+02  1.36822102e-02 -8.95997843e-01  8.01488939e+02]
# 3.1628723856046346 2.84 3.12 3.41
# 26 48
# Plotting fit to ESF for case 21, diameter 10.0 mm.
# Processing case 22, diameter 1.0 mm.
# [1.04884292e+01 1.84933404e-01 1.48617944e-01 2.16674039e+02]
# FWHM_0: 0.5246213409297894
# p1_0: [1.04884292e+01 1.84933404e-01 1.48617944e-01 2.16674039e+02]
# 0.5246213409297894 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 22, diameter 1.0 mm.
# Processing case 22, diameter 10.0 mm.
# [-11.14028123  -0.752176    -1.07830813 205.1626332 ]
# FWHM_0: 3.8064276961428187
# p1_0: [-11.14028123  -0.752176    -1.07830813 205.1626332 ]
# 3.8064276961428187 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 22, diameter 10.0 mm.
# Processing case 23, diameter 1.0 mm.
# [2.49269981e+01 5.90094528e-02 1.52376534e-01 2.02241756e+02]
# FWHM_0: 0.537889165660248
# p1_0: [2.49269981e+01 5.90094528e-02 1.52376534e-01 2.02241756e+02]
# 0.537889165660248 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 23, diameter 1.0 mm.
# Processing case 23, diameter 10.0 mm.
# [-22.04758871  -0.49804318  -1.15974119 205.32785134]
# FWHM_0: 4.093886407924947
# p1_0: [-22.04758871  -0.49804318  -1.15974119 205.32785134]
# 4.093886407924947 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 23, diameter 10.0 mm.
# Processing case 24, diameter 1.0 mm.
# [4.94809842e+01 2.77829895e-02 1.45461676e-01 1.77706968e+02]
# FWHM_0: 0.5134797146533024
# p1_0: [4.94809842e+01 2.77829895e-02 1.45461676e-01 1.77706968e+02]
# 0.5134797146533024 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 24, diameter 1.0 mm.
# Processing case 24, diameter 10.0 mm.
# [-47.39051924  -0.28178934  -1.28093324 205.65067316]
# FWHM_0: 4.521694354712396
# p1_0: [-47.39051924  -0.28178934  -1.28093324 205.65067316]
# 4.521694354712396 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 24, diameter 10.0 mm.
# Processing case 25, diameter 1.0 mm.
# [6.74887791e+00 1.38101238e-01 9.55422928e-02 1.23619914e+02]
# FWHM_0: 0.3372642937439419
# p1_0: [6.74887791e+00 1.38101238e-01 9.55422928e-02 1.23619914e+02]
# 0.3372642937439419 0.15 0.3 0.44999999999999996
# 35 39
# Plotting fit to ESF for case 25, diameter 1.0 mm.
# Processing case 25, diameter 10.0 mm.
# [  5.88035646   0.62655972   1.37153274 114.81524995]
# FWHM_0: 4.841510554920186
# p1_0: [  5.88035646   0.62655972   1.37153274 114.81524995]
# 4.841510554920186 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 25, diameter 10.0 mm.
# Processing case 26, diameter 1.0 mm.
# [1.50166188e+01 3.54973985e-02 1.26115831e-01 1.15367416e+02]
# FWHM_0: 0.445188881716554
# p1_0: [1.50166188e+01 3.54973985e-02 1.26115831e-01 1.15367416e+02]
# 0.445188881716554 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 26, diameter 1.0 mm.
# Processing case 26, diameter 10.0 mm.
# [-13.42008154   0.4109506   -1.37185507 120.8297826 ]
# FWHM_0: 4.842648407194751
# p1_0: [-13.42008154   0.4109506   -1.37185507 120.8297826 ]
# 4.842648407194751 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 26, diameter 10.0 mm.
# Processing case 27, diameter 1.0 mm.
# [2.91282690e+01 1.73716558e-02 1.35098235e-01 1.01263380e+02]
# FWHM_0: 0.47689676819601307
# p1_0: [2.91282690e+01 1.73716558e-02 1.35098235e-01 1.01263380e+02]
# 0.47689676819601307 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 27, diameter 1.0 mm.
# Processing case 27, diameter 10.0 mm.
# [-2.70426904e+01  3.33183476e-02 -1.39147041e+00  1.20967430e+02]
# FWHM_0: 4.91189053098233
# p1_0: [-2.70426904e+01  3.33183476e-02 -1.39147041e+00  1.20967430e+02]
# 4.91189053098233 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 27, diameter 10.0 mm.
# Processing case 28, diameter 1.0 mm.
# [ 3.47465868e+02 -8.89595255e-03  4.92482544e-01  7.84349799e+03]
# FWHM_0: 1.7384633798758118
# p1_0: [ 3.47465868e+02 -8.89595255e-03  4.92482544e-01  7.84349799e+03]
# 1.7384633798758118 1.51 1.6600000000000001 1.8199999999999998
# 26 48
# Plotting fit to ESF for case 28, diameter 1.0 mm.
# Processing case 28, diameter 10.0 mm.
# [-2.68857437e+02  3.69321934e-02 -1.09978578e+00  6.25164744e+03]
# FWHM_0: 3.8822437986030196
# p1_0: [-2.68857437e+02  3.69321934e-02 -1.09978578e+00  6.25164744e+03]
# 3.8822437986030196 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 28, diameter 10.0 mm.
# Processing case 29, diameter 1.0 mm.
# [-8.40365736e+02 -1.92542134e-02 -4.97679306e-01  8.19403257e+03]
# FWHM_0: 1.756807948917919
# p1_0: [-8.40365736e+02 -1.92542134e-02 -4.97679306e-01  8.19403257e+03]
# 1.756807948917919 1.6600000000000001 1.8199999999999998 1.9700000000000002
# 25 49
# Plotting fit to ESF for case 29, diameter 1.0 mm.
# Processing case 29, diameter 10.0 mm.
# [-6.47184395e+02  3.11997764e-02 -1.08510104e+00  6.25426897e+03]
# FWHM_0: 3.8304066537821306
# p1_0: [-6.47184395e+02  3.11997764e-02 -1.08510104e+00  6.25426897e+03]
# 3.8304066537821306 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 29, diameter 10.0 mm.
# Processing case 30, diameter 1.0 mm.
# [-1.65577289e+03 -1.27724245e-02 -5.03134655e-01  8.19945095e+03]
# FWHM_0: 1.7760653333507666
# p1_0: [-1.65577289e+03 -1.27724245e-02 -5.03134655e-01  8.19945095e+03]
# 1.7760653333507666 1.6600000000000001 1.8199999999999998 1.9700000000000002
# 25 49
# Plotting fit to ESF for case 30, diameter 1.0 mm.
# Processing case 30, diameter 10.0 mm.
# [1.24992048e+03 4.20343983e-02 1.06536962e+00 5.00820304e+03]
# FWHM_0: 3.7607547681849014
# p1_0: [1.24992048e+03 4.20343983e-02 1.06536962e+00 5.00820304e+03]
# 3.7607547681849014 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 30, diameter 10.0 mm.
# Processing case 31, diameter 1.0 mm.
# [-8.76032954e+01 -7.91183881e-03 -2.77130813e-01  2.07074070e+03]
# FWHM_0: 0.9782717687114972
# p1_0: [-8.76032954e+01 -7.91183881e-03 -2.77130813e-01  2.07074070e+03]
# 0.9782717687114972 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 31, diameter 1.0 mm.
# Processing case 31, diameter 10.0 mm.
# [-1.07935913e+02 -2.48751224e-01 -1.36276243e+00  2.06984899e+03]
# FWHM_0: 4.810551374995559
# p1_0: [-1.07935913e+02 -2.48751224e-01 -1.36276243e+00  2.06984899e+03]
# 4.810551374995559 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 31, diameter 10.0 mm.
# Processing case 32, diameter 1.0 mm.
# [-2.10488645e+02 -1.91724903e-02 -2.66215124e-01  2.07099705e+03]
# FWHM_0: 0.9397393862311504
# p1_0: [-2.10488645e+02 -1.91724903e-02 -2.66215124e-01  2.07099705e+03]
# 0.9397393862311504 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 32, diameter 1.0 mm.
# Processing case 32, diameter 10.0 mm.
# [-2.28122236e+02 -7.97454960e-02 -1.28021485e+00  2.07105063e+03]
# FWHM_0: 4.519158412210625
# p1_0: [-2.28122236e+02 -7.97454960e-02 -1.28021485e+00  2.07105063e+03]
# 4.519158412210625 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 32, diameter 10.0 mm.
# Processing case 33, diameter 1.0 mm.
# [-4.25682811e+02  1.01897259e-02 -2.62738478e-01  2.07144827e+03]
# FWHM_0: 0.9274668276543095
# p1_0: [-4.25682811e+02  1.01897259e-02 -2.62738478e-01  2.07144827e+03]
# 0.9274668276543095 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 33, diameter 1.0 mm.
# Processing case 33, diameter 10.0 mm.
# [-4.50802866e+02  9.61909897e-03 -1.30058359e+00  2.07371280e+03]
# FWHM_0: 4.591060089297693
# p1_0: [-4.50802866e+02  9.61909897e-03 -1.30058359e+00  2.07371280e+03]
# 4.591060089297693 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 33, diameter 10.0 mm.
# Processing case 34, diameter 1.0 mm.
# [-4.38875064e+01  2.58501757e-02 -2.12534909e-01  1.18347063e+03]
# FWHM_0: 0.7502482276151788
# p1_0: [-4.38875064e+01  2.58501757e-02 -2.12534909e-01  1.18347063e+03]
# 0.7502482276151788 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 34, diameter 1.0 mm.
# Processing case 34, diameter 10.0 mm.
# [-6.32505692e+01 -1.80283645e-01 -1.47415189e+00  1.19466124e+03]
# FWHM_0: 5.203756188459868
# p1_0: [-6.32505692e+01 -1.80283645e-01 -1.47415189e+00  1.19466124e+03]
# 5.203756188459868 4.82 5.11 5.390000000000001
# 19 55
# Plotting fit to ESF for case 34, diameter 10.0 mm.
# Processing case 35, diameter 1.0 mm.
# [-1.15514417e+02 -3.43317307e-04 -2.10132488e-01  1.18355715e+03]
# FWHM_0: 0.7417676813171947
# p1_0: [-1.15514417e+02 -3.43317307e-04 -2.10132488e-01  1.18355715e+03]
# 0.7417676813171947 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 35, diameter 1.0 mm.
# Processing case 35, diameter 10.0 mm.
# [-1.34762040e+02 -8.85985170e-02 -1.37897956e+00  1.19540163e+03]
# FWHM_0: 4.867797861609255
# p1_0: [-1.34762040e+02 -8.85985170e-02 -1.37897956e+00  1.19540163e+03]
# 4.867797861609255 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 35, diameter 10.0 mm.
# Processing case 36, diameter 1.0 mm.
# [-2.39634764e+02  3.02086538e-03 -2.04776204e-01  1.18359219e+03]
# FWHM_0: 0.7228600010127072
# p1_0: [-2.39634764e+02  3.02086538e-03 -2.04776204e-01  1.18359219e+03]
# 0.7228600010127072 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 36, diameter 1.0 mm.
# Processing case 36, diameter 10.0 mm.
# [-2.61135315e+02  4.63076449e-02 -1.40232154e+00  1.19748109e+03]
# FWHM_0: 4.950195050890972
# p1_0: [-2.61135315e+02  4.63076449e-02 -1.40232154e+00  1.19748109e+03]
# 4.950195050890972 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 36, diameter 10.0 mm.
# Processing case 37, diameter 1.0 mm.
# [-5.48398354e+01  6.06673352e-03 -2.28277640e-01  1.41454517e+03]
# FWHM_0: 0.8058200690835449
# p1_0: [-5.48398354e+01  6.06673352e-03 -2.28277640e-01  1.41454517e+03]
# 0.8058200690835449 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 37, diameter 1.0 mm.
# Processing case 37, diameter 10.0 mm.
# [-6.40962270e+01  2.78881121e-02 -7.24861550e-01  1.35717673e+03]
# FWHM_0: 2.5587612721457274
# p1_0: [-6.40962270e+01  2.78881121e-02 -7.24861550e-01  1.35717673e+03]
# 2.5587612721457274 2.27 2.55 2.84
# 28 46
# Plotting fit to ESF for case 37, diameter 10.0 mm.
# Processing case 38, diameter 1.0 mm.
# [-1.39742469e+02 -9.42113640e-04 -1.94219106e-01  1.41465447e+03]
# FWHM_0: 0.6855934429271843
# p1_0: [-1.39742469e+02 -9.42113640e-04 -1.94219106e-01  1.41465447e+03]
# 0.6855934429271843 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 38, diameter 1.0 mm.
# Processing case 38, diameter 10.0 mm.
# [-1.52826054e+02  1.08051494e-02 -8.63712700e-01  1.35770284e+03]
# FWHM_0: 3.0489058309888306
# p1_0: [-1.52826054e+02  1.08051494e-02 -8.63712700e-01  1.35770284e+03]
# 3.0489058309888306 2.84 3.12 3.41
# 26 48
# Plotting fit to ESF for case 38, diameter 10.0 mm.
# Processing case 39, diameter 1.0 mm.
# [-2.87151944e+02  4.58398893e-03 -1.72117154e-01  1.41465845e+03]
# FWHM_0: 0.6075735527892061
# p1_0: [-2.87151944e+02  4.58398893e-03 -1.72117154e-01  1.41465845e+03]
# 0.6075735527892061 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 39, diameter 1.0 mm.
# Processing case 39, diameter 10.0 mm.
# [-2.73702240e+02  6.98034551e-03 -8.96931588e-01  1.35842135e+03]
# FWHM_0: 3.1661685055884807
# p1_0: [-2.73702240e+02  6.98034551e-03 -8.96931588e-01  1.35842135e+03]
# 3.1661685055884807 2.84 3.12 3.41
# 26 48
# Plotting fit to ESF for case 39, diameter 10.0 mm.
# Processing case 40, diameter 1.0 mm.
# [-9.90386492e+00  3.12674979e-01 -5.78368916e-02  3.76148141e+02]
# FWHM_0: 0.2041642274141384
# p1_0: [-9.90386492e+00  3.12674979e-01 -5.78368916e-02  3.76148141e+02]
# 0.2041642274141384 0.0 0.15 0.3
# 36 38
# Plotting fit to ESF for case 40, diameter 1.0 mm.
# Processing case 40, diameter 10.0 mm.
# [-22.90299444  -0.76906792  -1.09628445 352.67831855]
# FWHM_0: 3.869884119290925
# p1_0: [-22.90299444  -0.76906792  -1.09628445 352.67831855]
# 3.869884119290925 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 40, diameter 10.0 mm.
# Processing case 41, diameter 1.0 mm.
# [3.43748043e+01 5.97459380e-02 1.60820824e-01 3.41829761e+02]
# FWHM_0: 0.5676975100310281
# p1_0: [3.43748043e+01 5.97459380e-02 1.60820824e-01 3.41829761e+02]
# 0.5676975100310281 0.44999999999999996 0.61 0.76
# 33 41
# Plotting fit to ESF for case 41, diameter 1.0 mm.
# Processing case 41, diameter 10.0 mm.
# [-41.33094412  -0.53381949  -1.15733471 352.96513423]
# FWHM_0: 4.085391534414732
# p1_0: [-41.33094412  -0.53381949  -1.15733471 352.96513423]
# 4.085391534414732 3.69 3.97 4.26
# 23 51
# Plotting fit to ESF for case 41, diameter 10.0 mm.
# Processing case 42, diameter 1.0 mm.
# [7.70757030e+01 2.88910615e-02 1.47037842e-01 2.99155555e+02]
# FWHM_0: 0.5190435811019662
# p1_0: [7.70757030e+01 2.88910615e-02 1.47037842e-01 2.99155555e+02]
# 0.5190435811019662 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 42, diameter 1.0 mm.
# Processing case 42, diameter 10.0 mm.
# [-8.27659097e+01 -3.04486537e-01 -1.28879050e+00  3.53587448e+02]
# FWHM_0: 4.549430450029011
# p1_0: [-8.27659097e+01 -3.04486537e-01 -1.28879050e+00  3.53587448e+02]
# 4.549430450029011 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 42, diameter 10.0 mm.
# Processing case 43, diameter 1.0 mm.
# [1.48905750e+01 8.58039340e-02 1.22806027e-01 2.06638593e+02]
# FWHM_0: 0.4335052759974672
# p1_0: [1.48905750e+01 8.58039340e-02 1.22806027e-01 2.06638593e+02]
# 0.4335052759974672 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 43, diameter 1.0 mm.
# Processing case 43, diameter 10.0 mm.
# [-10.72524878  -0.53150852  -1.03335744 203.15046768]
# FWHM_0: 3.6477517662217496
# p1_0: [-10.72524878  -0.53150852  -1.03335744 203.15046768]
# 3.6477517662217496 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 43, diameter 10.0 mm.
# Processing case 44, diameter 1.0 mm.
# [2.81999022e+01 1.48551581e-02 1.32255397e-01 1.93344072e+02]
# FWHM_0: 0.4668615515491201
# p1_0: [2.81999022e+01 1.48551581e-02 1.32255397e-01 1.93344072e+02]
# 0.4668615515491201 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 44, diameter 1.0 mm.
# Processing case 44, diameter 10.0 mm.
# [-2.36641393e+01 -7.72894144e-02 -1.34888757e+00  2.03612247e+02]
# FWHM_0: 4.761573128607231
# p1_0: [-2.36641393e+01 -7.72894144e-02 -1.34888757e+00  2.03612247e+02]
# 4.761573128607231 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 44, diameter 10.0 mm.
# Processing case 45, diameter 1.0 mm.
# [5.20376643e+01 1.26410464e-02 1.37606056e-01 1.69513545e+02]
# FWHM_0: 0.48574937910342014
# p1_0: [5.20376643e+01 1.26410464e-02 1.37606056e-01 1.69513545e+02]
# 0.48574937910342014 0.3 0.44999999999999996 0.61
# 34 40
# Plotting fit to ESF for case 45, diameter 1.0 mm.
# Processing case 45, diameter 10.0 mm.
# [-4.48620435e+01 -1.46589270e-01 -1.36423263e+00  2.03870508e+02]
# FWHM_0: 4.8157411897061255
# p1_0: [-4.48620435e+01 -1.46589270e-01 -1.36423263e+00  2.03870508e+02]
# 4.8157411897061255 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 45, diameter 10.0 mm.
# Processing case 46, diameter 1.0 mm.
# [-5.79621496e+02  1.78838304e-02 -4.58749361e-01  1.37762327e+04]
# FWHM_0: 1.6193852460879086
# p1_0: [-5.79621496e+02  1.78838304e-02 -4.58749361e-01  1.37762327e+04]
# 1.6193852460879086 1.51 1.6600000000000001 1.8199999999999998
# 26 48
# Plotting fit to ESF for case 46, diameter 1.0 mm.
# Processing case 46, diameter 10.0 mm.
# [ 5.20016204e+02 -3.72738080e-03  1.05066234e+00  1.02418951e+04]
# FWHM_0: 3.7088380619240655
# p1_0: [ 5.20016204e+02 -3.72738080e-03  1.05066234e+00  1.02418951e+04]
# 3.7088380619240655 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 46, diameter 10.0 mm.
# Processing case 47, diameter 1.0 mm.
# [-1.40363698e+03 -1.24519660e-02 -4.78345557e-01  1.37811348e+04]
# FWHM_0: 1.6885598146431018
# p1_0: [-1.40363698e+03 -1.24519660e-02 -4.78345557e-01  1.37811348e+04]
# 1.6885598146431018 1.51 1.6600000000000001 1.8199999999999998
# 26 48
# Plotting fit to ESF for case 47, diameter 1.0 mm.
# Processing case 47, diameter 10.0 mm.
# [-1.16950684e+03  6.45128851e-03 -1.06870803e+00  1.07663324e+04]
# FWHM_0: 3.7725393318814233
# p1_0: [-1.16950684e+03  6.45128851e-03 -1.06870803e+00  1.07663324e+04]
# 3.7725393318814233 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 47, diameter 10.0 mm.
# Processing case 48, diameter 1.0 mm.
# [-2.77224532e+03 -1.57062037e-03 -4.87677610e-01  1.37901215e+04]
# FWHM_0: 1.7215019638386184
# p1_0: [-2.77224532e+03 -1.57062037e-03 -4.87677610e-01  1.37901215e+04]
# 1.7215019638386184 1.51 1.6600000000000001 1.8199999999999998
# 26 48
# Plotting fit to ESF for case 48, diameter 1.0 mm.
# Processing case 48, diameter 10.0 mm.
# [-2.20567099e+03  3.01655286e-02 -1.05961759e+00  1.07730295e+04]
# FWHM_0: 3.740450107720391
# p1_0: [-2.20567099e+03  3.01655286e-02 -1.05961759e+00  1.07730295e+04]
# 3.740450107720391 3.41 3.69 3.97
# 24 50
# Plotting fit to ESF for case 48, diameter 10.0 mm.
# Processing case 49, diameter 1.0 mm.
# [1.54066568e+02 5.31641065e-02 2.88122693e-01 3.38763293e+03]
# FWHM_0: 1.0170731053886115
# p1_0: [1.54066568e+02 5.31641065e-02 2.88122693e-01 3.38763293e+03]
# 1.0170731053886115 0.9099999999999999 1.06 1.21
# 30 44
# Plotting fit to ESF for case 49, diameter 1.0 mm.
# Processing case 49, diameter 10.0 mm.
# [ 1.77103331e+02 -4.27618413e-01  1.30252492e+00  3.35325541e+03]
# FWHM_0: 4.5979129512267995
# p1_0: [ 1.77103331e+02 -4.27618413e-01  1.30252492e+00  3.35325541e+03]
# 4.5979129512267995 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 49, diameter 10.0 mm.
# Processing case 50, diameter 1.0 mm.
# [3.62643120e+02 5.42513238e-03 2.72727236e-01 3.17945586e+03]
# FWHM_0: 0.9627271429188067
# p1_0: [3.62643120e+02 5.42513238e-03 2.72727236e-01 3.17945586e+03]
# 0.9627271429188067 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 50, diameter 1.0 mm.
# Processing case 50, diameter 10.0 mm.
# [ 3.83584729e+02 -1.74428748e-01  1.26616124e+00  3.14895878e+03]
# FWHM_0: 4.469549173731658
# p1_0: [ 3.83584729e+02 -1.74428748e-01  1.26616124e+00  3.14895878e+03]
# 4.469549173731658 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 50, diameter 10.0 mm.
# Processing case 51, diameter 1.0 mm.
# [7.34718429e+02 2.24525386e-02 2.64556973e-01 2.80817761e+03]
# FWHM_0: 0.9338861156415307
# p1_0: [7.34718429e+02 2.24525386e-02 2.64556973e-01 2.80817761e+03]
# 0.9338861156415307 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 51, diameter 1.0 mm.
# Processing case 51, diameter 10.0 mm.
# [ 7.67370709e+02 -4.68089215e-02  1.29957196e+00  2.76978458e+03]
# FWHM_0: 4.5874890355126015
# p1_0: [ 7.67370709e+02 -4.68089215e-02  1.29957196e+00  2.76978458e+03]
# 4.5874890355126015 4.26 4.54 4.82
# 21 53
# Plotting fit to ESF for case 51, diameter 10.0 mm.
# Processing case 52, diameter 1.0 mm.
# [-8.23748343e+01  4.14613022e-02 -2.42445454e-01  2.03740421e+03]
# FWHM_0: 0.8558324538047564
# p1_0: [-8.23748343e+01  4.14613022e-02 -2.42445454e-01  2.03740421e+03]
# 0.8558324538047564 0.76 0.9099999999999999 1.06
# 31 43
# Plotting fit to ESF for case 52, diameter 1.0 mm.
# Processing case 52, diameter 10.0 mm.
# [-1.04856389e+02 -2.48632300e-01 -1.32796084e+00  2.04518400e+03]
# FWHM_0: 4.687701761555686
# p1_0: [-1.04856389e+02 -2.48632300e-01 -1.32796084e+00  2.04518400e+03]
# 4.687701761555686 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 52, diameter 10.0 mm.
# Processing case 53, diameter 1.0 mm.
# [-2.02228848e+02  8.66655916e-03 -2.22842200e-01  2.03756798e+03]
# FWHM_0: 0.7866329654401149
# p1_0: [-2.02228848e+02  8.66655916e-03 -2.22842200e-01  2.03756798e+03]
# 0.7866329654401149 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 53, diameter 1.0 mm.
# Processing case 53, diameter 10.0 mm.
# [ 2.28390122e+02 -1.13114660e-01  1.32795209e+00  1.81826667e+03]
# FWHM_0: 4.687670894555679
# p1_0: [ 2.28390122e+02 -1.13114660e-01  1.32795209e+00  1.81826667e+03]
# 4.687670894555679 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 53, diameter 10.0 mm.
# Processing case 54, diameter 1.0 mm.
# [-4.14864561e+02  8.43978836e-03 -2.09786947e-01  2.03762493e+03]
# FWHM_0: 0.7405479227154879
# p1_0: [-4.14864561e+02  8.43978836e-03 -2.09786947e-01  2.03762493e+03]
# 0.7405479227154879 0.61 0.76 0.9099999999999999
# 32 42
# Plotting fit to ESF for case 54, diameter 1.0 mm.
# Processing case 54, diameter 10.0 mm.
# [-4.49021808e+02  2.04284311e-02 -1.39189005e+00  2.05044974e+03]
# FWHM_0: 4.91337187148985
# p1_0: [-4.49021808e+02  2.04284311e-02 -1.39189005e+00  2.05044974e+03]
# 4.91337187148985 4.54 4.82 5.11
# 20 54
# Plotting fit to ESF for case 54, diameter 10.0 mm.
#      case  diameter           0         1         2            3
# 0       1       1.0   13.086617  0.073581  0.146672   312.371161
# 1       1      10.0  -14.261071  0.060349 -0.900270   300.827549
# 2       2       1.0   33.609223  0.020294  0.165473   291.872833
# 3       2      10.0  -33.823904  0.082689 -0.941352   300.971430
# 4       3       1.0  -66.354016  0.016592 -0.162968   325.490270
# ..    ...       ...         ...       ...       ...          ...
# 103    52      10.0 -104.856389 -0.248632 -1.327961  2045.183996
# 104    53       1.0 -202.228848  0.008667 -0.222842  2037.567976
# 105    53      10.0  228.390122 -0.113115  1.327952  1818.266674
# 106    54       1.0 -414.864561  0.008440 -0.209787  2037.624926
# 107    54      10.0 -449.021808  0.020428 -1.391890  2050.449737
#
# [108 rows x 6 columns]

# %%
# plot the fit!
def plot_fit_to_ESF(df, Y_colname):
	case = df['case'].unique()[0]
	
	diameter = df['diameter'].unique()[0]

	print('Plotting fit to ESF for case {}, diameter {} mm.'.format(case, diameter))

	fname = '{}/ESF_fit_csv/case_{}_diameter_{}_mm_ESF_fit.csv'.format(master_folder,case,diameter)
	this_df = pd.read_csv(fname, index_col=0)

	X = this_df['x_pos_mm'].values
	Y_log_fermi_func = this_df['Y_log_fermi_func'].values

	Y = this_df[Y_colname].values

	fig, ax = plt.subplots(1)	
	ax.plot(X, Y_log_fermi_func, color='darkblue', label='ESF fit')
	
	ax.scatter(X, Y, edgecolor='darkorange', label='MCNP data', color='darkorange')
		
		# FWHM, Y_log_fermi_func, p1, r_squared = compute_FWHM(X, df_poisson.iloc[:,ii].values,rad)
		
	ax.tick_params('x', colors='black', labelsize=12)	
	ax.tick_params('y', colors='black', labelsize=12)	
	# grid
	ax.grid(b=True, which='major', linestyle='-')#, color='gray')
	ax.grid(b=True, which='minor', linestyle='--')#, color='gray')
	plt.title('Case: {:.0f}, Diameter: {:.2f} mm'.format(case, diameter))
	plt.legend(loc='best')
	plt.xlabel('Edge position [mm]')
	plt.ylabel('Countrate for tot. Neutron Yield: {:.1e} n/s'.format(S0))
	plt.tight_layout()
	# plt.show()
	plt.savefig('{}ESF_fit_plots/diameter_{:.2f}_mm_case_{:.0f}_ESF_fit.png'.format(master_folder, diameter, case), dpi=100)
	plt.clf()
	plt.close('all')

Y_colname = 'C_cutoff'
# df_MCNP_results.groupby(['case', 'diameter']).apply(lambda x: plot_fit_to_ESF(x, Y_colname)).reset_index()

# %%
# ----------------------------------------------------------------------------------------------------
# 	3. select +/- 1 FWHM of this fermi function and interpolate the fitted function
#	4. select 30 measurement points along that fitted function (use interpolation)
#	5. sample from poisson 1000 points for each of these positions
# ----------------------------------------------------------------------------------------------------

# +/-1 FWHM already taken in the last step

def interpolate_and_resample(df, Y_colname, num_measurements, tot_meas_time, num_samples):
	case = df['case'].unique()[0]
	
	diameter = df['diameter'].unique()[0]

	fname = '{}ESF_fit_csv/case_{}_diameter_{}_mm_ESF_fit.csv'.format(master_folder,case,diameter)

	df_ESF = pd.read_csv(fname, index_col=0)

	X = df_ESF['x_pos_mm'].values
	Y = df_ESF['Y_log_fermi_func'].values
	Y_mcnp = df_ESF[Y_colname].values
	
	# interpolate
	interp_ESF = interp1d(X, Y, kind='cubic')  # angle is in radian
	qry_X = np.linspace(np.min(X), np.max(X), num=num_measurements, endpoint=True)
	qry_Y = interp_ESF(qry_X)

	# take measurement time into account
	# time per position
	time_per_pos = (tot_meas_time*60*60) / num_measurements  # convert from hour to second and then divide by number of measurements
	
	qry_Y = np.multiply(qry_Y, time_per_pos) 
	Y_mcnp = np.multiply(Y_mcnp, time_per_pos)
	Y = np.multiply(Y, time_per_pos)

	# PLOT
	# print('Plotting interpolated fit to ESF for case {}, diameter {} mm.'.format(case, diameter))
	# fig, ax = plt.subplots(1)	
	# ax.plot(X, Y, color='black', label='ESF fit')
	
	# ax.scatter(X, Y_mcnp, edgecolor='black', label='MCNP data', color='darkorange', s=70)
	# ax.scatter(qry_X, qry_Y, marker='x', edgecolor='red', label='Interpolated fit', color='red', s=25)
		
	# # FWHM, Y_log_fermi_func, p1, r_squared = compute_FWHM(X, df_poisson.iloc[:,ii].values,rad)
		
	# ax.tick_params('x', colors='black', labelsize=12)	
	# ax.tick_params('y', colors='black', labelsize=12)	
	# # grid
	# ax.grid(b=True, which='major', linestyle='-')#, color='gray')
	# ax.grid(b=True, which='minor', linestyle='--')#, color='gray')
	# plt.title('Case: {:.0f}, Diameter: {:.2f} mm, tot. meas time {:.0f} h'.format(case, diameter, time_per_pos))
	# plt.legend(loc='best')
	# plt.xlabel('Edge position [mm]')
	# plt.ylabel('Counts for tot. Neutron Yield: {:.1e} n/s'.format(S0))
	# plt.tight_layout()
	# plt.show()
	# # plt.savefig('./ESF_fit/interpolate_fitted_ESF_diameter_{:.2f}_mm_case_{:.0f}_ESF_fit.png'.format(diameter, case), dpi=300)
	# # plt.clf()
	# # plt.close('all')

	# add poisson noise to the fitted data(!). Noise is added to the FIT, not to the MCNP data
	this_df = pd.DataFrame()
	this_df['x_pos_mm'] = qry_X
	this_df['counts'] = qry_Y

	
	df_poisson = this_df['counts'].apply(lambda x: pd.Series(np.random.poisson(x, size=num_samples)))
	df_poisson['x_pos_mm'] = this_df['x_pos_mm']
	df_poisson['counts'] = this_df['counts']

	# PLOT
	print('Plotting interpolated fit and poisson noise to ESF for case {}, diameter {} mm.'.format(case, diameter))
	fig, ax = plt.subplots(1)	
	ax.plot(X, Y, color='black', label='ESF fit')
	
	# ax.scatter(X, Y_mcnp, edgecolor='black', label='MCNP data', color='darkorange', s=70)
	ax.scatter(qry_X, qry_Y, marker='x', edgecolor='red', label='Interpolated fit', color='red', s=25)
	for ii in range(0, 3):
		ax.scatter(df_poisson['x_pos_mm'].values, df_poisson.iloc[:,ii].values, marker='o', label='Poisson noise', s=25)
		
	# FWHM, Y_log_fermi_func, p1, r_squared = compute_FWHM(X, df_poisson.iloc[:,ii].values,rad)
		
	ax.tick_params('x', colors='black', labelsize=12)	
	ax.tick_params('y', colors='black', labelsize=12)	
	# grid
	ax.grid(b=True, which='major', linestyle='-')#, color='gray')
	ax.grid(b=True, which='minor', linestyle='--')#, color='gray')
	plt.title('Case: {:.0f}, Diameter: {:.2f} mm, time per pos {:.0f} s'.format(case, diameter, time_per_pos))
	plt.legend(loc='best')
	plt.xlabel('Edge position [mm]')
	plt.ylabel('Counts for tot. Neutron Yield: {:.1e} n/s'.format(S0))
	plt.tight_layout()
	# plt.show()
	plt.savefig('{}noised_ESF_fit_plots/noised_interpolatd_fitted_ESF_diameter_{:.2f}_mm_case_{:.0f}_ESF_fit.png'.format(master_folder, diameter, case), dpi=100)
	plt.clf()
	plt.close('all')

	fname = '{}noised_ESF_fit_csv/case_{}_diameter_{}_mm_tot_time_{}_hrs.csv'.format(master_folder,case,diameter, tot_meas_time)
	df_poisson.to_csv(fname)



# import the fitted data
Y_colname = 'C_cutoff'
num_measurements = 30  # number of measurements (edge positions) for one experimental setup
tot_meas_time = 5  # total measurement time in hours
num_samples = 1000  # number of poisson samples
df_MCNP_results.groupby(['case', 'diameter']).apply(lambda x: interpolate_and_resample(x, Y_colname, num_measurements, tot_meas_time, num_samples)).reset_index()
# Out:
# Plotting interpolated fit and poisson noise to ESF for case 1, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 1, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 2, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 2, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 3, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 3, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 4, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 4, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 5, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 5, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 6, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 6, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 7, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 7, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 8, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 8, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 9, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 9, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 10, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 10, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 11, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 11, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 12, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 12, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 13, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 13, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 14, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 14, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 15, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 15, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 16, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 16, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 17, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 17, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 18, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 18, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 19, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 19, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 20, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 20, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 21, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 21, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 22, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 22, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 23, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 23, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 24, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 24, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 25, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 25, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 26, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 26, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 27, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 27, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 28, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 28, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 29, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 29, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 30, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 30, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 31, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 31, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 32, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 32, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 33, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 33, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 34, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 34, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 35, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 35, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 36, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 36, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 37, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 37, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 38, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 38, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 39, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 39, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 40, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 40, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 41, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 41, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 42, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 42, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 43, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 43, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 44, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 44, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 45, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 45, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 46, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 46, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 47, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 47, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 48, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 48, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 49, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 49, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 50, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 50, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 51, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 51, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 52, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 52, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 53, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 53, diameter 10.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 54, diameter 1.0 mm.
# Plotting interpolated fit and poisson noise to ESF for case 54, diameter 10.0 mm.
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
# ----------------------------------------------------------------------------------------------------
#	6. analog to 2, re-compute logistic fermi function to ESF --> obtain 1000 FWHMs as p[2]*3.53 
# ----------------------------------------------------------------------------------------------------

def fit_FWHM_to_poisson(df, tot_meas_time):

	case = df['case'].unique()[0]
	diameter = df['diameter'].unique()[0]
	if case > -1:

	# if (case == 30) & (diameter > 12.0):
			# if case == 0:
		

		fname = '{}noised_ESF_fit_csv/case_{}_diameter_{}_mm_tot_time_{}_hrs.csv'.format(master_folder,case,diameter, tot_meas_time)
		
		df_ESF = pd.read_csv(fname, index_col=0)

		print('Processing FWHM of poisson noised fit case {}, diameter {} mm.'.format(case, diameter))

		X = df_ESF['x_pos_mm'].values
		Y = df_ESF['counts'].values

		# find the optimal p0 as initial guess for the fit, then use that to return the FWHM
		# m = np.mean(Y[0:5])
		# m = [1e6, 1e7, 1e8, 1e9, 1e10]
		m = [1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10, np.max(Y)]
		a = [1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
		b = [1e-3, 1e-2, 2e-2, 3e-2, 4e-2, 5e-2, 1e-3, 5e-3, 1e-4]
		c = [0.5, 2, 4, 6, 8, 10, 15, 20, 30]
		for kk in list(itertools.product(a,b,c,m)):
			
		# for kk in list(itertools.product(a,b,c)):
			p0 = [-kk[0], kk[1], kk[2]/3.53, kk[3]] # Initial guess for the parameters	
			FWHM_0, Y_log_fermi_func_0, p1_0, r_squared_0 = fun_calculate_FWHM_of_ESF(X, Y, p0)
			FWHM_0 = np.abs(FWHM_0)
			diff_fit =np.abs(Y_log_fermi_func_0[0]-Y_log_fermi_func_0[-1])
			diff_Y = np.abs(Y[0]-Y[-1])
			if (np.abs(FWHM_0) > 1e-1) & (np.abs(FWHM_0) < 2*diameter) & (np.divide(np.abs(diff_fit-diff_Y), diff_Y) < 0.5 ):  # computed FWHM larger than 0

				print(p1_0)
				break


		if FWHM_0 > 100:
			print('FWHM {} LARGER THAN 100! Exit.'.format(FWHM_0))
			sys.exit()
		print('FWHM_0: {} '.format(FWHM_0))
		print('p1_0: {}'.format(p1_0))
		
		# fit for the poisson noise
		cols = df_ESF.columns
		cols = [col for col in cols if re.search(r'\d', col)]

		df_ESF = df_ESF[cols]

		for ii in range(0,len(df_ESF.columns)):
			Y = df_ESF.iloc[:,ii].values
			FWHM, Y_log_fermi_func, p1, r_squared = fun_calculate_FWHM_of_ESF(X, Y, p1_0)
			FWHM = np.abs(FWHM)
			if ii == 0:
				s1 = pd.Series([FWHM], index=['FWHM_{:.0f}'.format(ii)])
			else:
				s1 = s1.append(pd.Series([FWHM], index=['FWHM_{:.0f}'.format(ii)]))

		s1 = s1.append(pd.Series([FWHM_0], index=['FWHM_orig']))
		# n, bins, patches = plt.hist(s1, 100, facecolor='g', alpha=0.75)
		# plt.plot([FWHM_0, FWHM_0], [0, np.max(n)], color='red')
		# plt.xlabel('FWHM')
		# plt.ylabel('Counted')
		# plt.grid(True)
		# # plt.show()
		# plt.savefig('./FWHM_on_poisson/noised_interpolated_fitted_ESF_diameter_{:.2f}_mm_case_{:.0f}_ESF_fit.png'.format(diameter, case), dpi=300)
		# plt.clf()
		# plt.close('all')
		

		# # a.set_index('idx', inplace=True)


		

		return s1


# # change only if needs recomputation for some reason
# # tot_meas_time = 3  # total measurement time in hours

df_poisson = df_MCNP_results.groupby(['case', 'diameter']).apply(lambda x: fit_FWHM_to_poisson(x, tot_meas_time)).reset_index()
fname = '{}FWHM_on_poisson_tot_time_{}_hrs.csv'.format(master_folder,tot_meas_time)
df_poisson.to_csv(fname)
# Out:
# Processing FWHM of poisson noised fit case 1, diameter 1.0 mm.
# [-8.18365233e+03  8.57604395e-02 -1.59118483e-01  1.95555309e+05]
# FWHM_0: 0.5616882441337896
# p1_0: [-8.18365233e+03  8.57604395e-02 -1.59118483e-01  1.95555309e+05]
# Processing FWHM of poisson noised fit case 1, diameter 10.0 mm.
# [-9.07978177e+03  7.38037133e-02 -1.01154071e+00  1.80778008e+05]
# FWHM_0: 3.5707387152724563
# p1_0: [-9.07978177e+03  7.38037133e-02 -1.01154071e+00  1.80778008e+05]
# Processing FWHM of poisson noised fit case 2, diameter 1.0 mm.
# [-2.07677367e+04  2.48903361e-02 -1.75846251e-01  1.95686283e+05]
# FWHM_0: 0.6207372667604779
# p1_0: [-2.07677367e+04  2.48903361e-02 -1.75846251e-01  1.95686283e+05]
# Processing FWHM of poisson noised fit case 2, diameter 10.0 mm.
# [-2.18087372e+04  1.14487624e-01 -1.07920046e+00  1.81458175e+05]
# FWHM_0: 3.8095776403485253
# p1_0: [-2.18087372e+04  1.14487624e-01 -1.07920046e+00  1.81458175e+05]
# Processing FWHM of poisson noised fit case 3, diameter 1.0 mm.
# [-4.08310811e+04  1.66218601e-02 -1.71926857e-01  1.95801490e+05]
# FWHM_0: 0.6069018043911487
# p1_0: [-4.08310811e+04  1.66218601e-02 -1.71926857e-01  1.95801490e+05]
# Processing FWHM of poisson noised fit case 3, diameter 10.0 mm.
# [-3.94996635e+04  8.75596131e-02 -1.06222709e+00  1.82426641e+05]
# FWHM_0: 3.749661611140467
# p1_0: [-3.94996635e+04  8.75596131e-02 -1.06222709e+00  1.82426641e+05]
# Processing FWHM of poisson noised fit case 4, diameter 1.0 mm.
# [-2.98998199e+03  1.13756658e-01 -1.73247475e-01  5.11098878e+04]
# FWHM_0: 0.6115635855271514
# p1_0: [-2.98998199e+03  1.13756658e-01 -1.73247475e-01  5.11098878e+04]
# Processing FWHM of poisson noised fit case 4, diameter 10.0 mm.
# [2.34411762e+03 9.69044735e-02 1.37494998e+00 4.38030306e+04]
# FWHM_0: 4.853573423884957
# p1_0: [2.34411762e+03 9.69044735e-02 1.37494998e+00 4.38030306e+04]
# Processing FWHM of poisson noised fit case 5, diameter 1.0 mm.
# [-6.40244758e+03  3.27968353e-02 -1.63368183e-01  5.11710205e+04]
# FWHM_0: 0.5766896855271704
# p1_0: [-6.40244758e+03  3.27968353e-02 -1.63368183e-01  5.11710205e+04]
# Processing FWHM of poisson noised fit case 5, diameter 10.0 mm.
# [-4.88539000e+03 -4.33165245e-02 -1.39523509e+00  4.63186372e+04]
# FWHM_0: 4.9251798668393185
# p1_0: [-4.88539000e+03 -4.33165245e-02 -1.39523509e+00  4.63186372e+04]
# Processing FWHM of poisson noised fit case 6, diameter 1.0 mm.
# [-1.18630373e+04  1.50643284e-02 -1.53378913e-01  5.12397180e+04]
# FWHM_0: 0.5414275645257178
# p1_0: [-1.18630373e+04  1.50643284e-02 -1.53378913e-01  5.12397180e+04]
# Processing FWHM of poisson noised fit case 6, diameter 10.0 mm.
# [-1.11284200e+04 -7.40487123e-02 -1.54882140e+00  4.67468660e+04]
# FWHM_0: 5.4673395347588905
# p1_0: [-1.11284200e+04 -7.40487123e-02 -1.54882140e+00  4.67468660e+04]
# Processing FWHM of poisson noised fit case 7, diameter 1.0 mm.
# [-1.27887159e+03  1.31257509e-01 -1.42053306e-01  2.89938707e+04]
# FWHM_0: 0.5014481704567163
# p1_0: [-1.27887159e+03  1.31257509e-01 -1.42053306e-01  2.89938707e+04]
# Processing FWHM of poisson noised fit case 7, diameter 10.0 mm.
# [-1.44700045e+03  1.17812159e+00 -1.60116332e+00  2.70360925e+04]
# FWHM_0: 5.652106521492791
# p1_0: [-1.44700045e+03  1.17812159e+00 -1.60116332e+00  2.70360925e+04]
# /Users/hkromer/anaconda3/envs/py3.7/lib/python3.7/site-packages/scipy/optimize/minpack.py:449: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# Processing FWHM of poisson noised fit case 8, diameter 1.0 mm.
# [3.29889316e+03 4.46820042e-03 1.48174084e-01 2.57033263e+04]
# FWHM_0: 0.5230545151750127
# p1_0: [3.29889316e+03 4.46820042e-03 1.48174084e-01 2.57033263e+04]
# Processing FWHM of poisson noised fit case 8, diameter 10.0 mm.
# [-3.43184220e+03  8.73611116e-01 -1.70929949e+00  2.72395981e+04]
# FWHM_0: 6.033827184794999
# p1_0: [-3.43184220e+03  8.73611116e-01 -1.70929949e+00  2.72395981e+04]
# Processing FWHM of poisson noised fit case 9, diameter 1.0 mm.
# [ 6.42797251e+03 -2.37199949e-03  1.50665024e-01  2.26135444e+04]
# FWHM_0: 0.5318475349797506
# p1_0: [ 6.42797251e+03 -2.37199949e-03  1.50665024e-01  2.26135444e+04]
# Processing FWHM of poisson noised fit case 9, diameter 10.0 mm.
# [6.68512579e+03 8.34112331e-02 1.65253996e+00 2.05975418e+04]
# FWHM_0: 5.833466061803498
# p1_0: [6.68512579e+03 8.34112331e-02 1.65253996e+00 2.05975418e+04]
# Processing FWHM of poisson noised fit case 10, diameter 1.0 mm.
# [-8.44533211e+04  1.20749320e-02 -5.50698795e-01  1.81020966e+06]
# FWHM_0: 1.9439667463448913
# p1_0: [-8.44533211e+04  1.20749320e-02 -5.50698795e-01  1.81020966e+06]
# Processing FWHM of poisson noised fit case 10, diameter 10.0 mm.
# [-6.59873046e+04  2.24723498e-01 -1.37952982e+00  1.35821514e+06]
# FWHM_0: 4.869740270293499
# p1_0: [-6.59873046e+04  2.24723498e-01 -1.37952982e+00  1.35821514e+06]
# Processing FWHM of poisson noised fit case 11, diameter 1.0 mm.
# FWHM_0: 2.0370458617723894
# p1_0: [ 2.01608436e+05 -1.05908313e-02  5.77066816e-01  1.61373574e+06]
# Processing FWHM of poisson noised fit case 11, diameter 10.0 mm.
# [-1.52682917e+05  1.42247955e-01 -1.27652723e+00  1.36169423e+06]
# FWHM_0: 4.506141116120886
# p1_0: [-1.52682917e+05  1.42247955e-01 -1.27652723e+00  1.36169423e+06]
# Processing FWHM of poisson noised fit case 12, diameter 1.0 mm.
# FWHM_0: 2.120334580130778
# p1_0: [ 4.00700433e+05 -1.03361009e-02  6.00661354e-01  1.42578115e+06]
# Processing FWHM of poisson noised fit case 12, diameter 10.0 mm.
# [-2.96120733e+05  1.27138333e-01 -1.25060433e+00  1.36949785e+06]
# FWHM_0: 4.414633274582665
# p1_0: [-2.96120733e+05  1.27138333e-01 -1.25060433e+00  1.36949785e+06]
# Processing FWHM of poisson noised fit case 13, diameter 1.0 mm.
# [-1.99643702e+04  6.39951671e-02 -2.82044564e-01  4.49662489e+05]
# FWHM_0: 0.9956173093822912
# p1_0: [-1.99643702e+04  6.39951671e-02 -2.82044564e-01  4.49662489e+05]
# Processing FWHM of poisson noised fit case 13, diameter 10.0 mm.
# [-2.65839606e+04 -8.09801255e-02 -1.54276965e+00  4.50799629e+05]
# FWHM_0: 5.445976875380824
# p1_0: [-2.65839606e+04 -8.09801255e-02 -1.54276965e+00  4.50799629e+05]
# Processing FWHM of poisson noised fit case 14, diameter 1.0 mm.
# [4.77429191e+04 1.89044201e-03 2.90527414e-01 4.02695074e+05]
# FWHM_0: 1.0255617705085864
# p1_0: [4.77429191e+04 1.89044201e-03 2.90527414e-01 4.02695074e+05]
# Processing FWHM of poisson noised fit case 14, diameter 10.0 mm.
# [-5.41789262e+04  3.38141889e-02 -1.47238757e+00  4.52374452e+05]
# FWHM_0: 5.1975281066958186
# p1_0: [-5.41789262e+04  3.38141889e-02 -1.47238757e+00  4.52374452e+05]
# Processing FWHM of poisson noised fit case 15, diameter 1.0 mm.
# [9.55925496e+04 1.86298841e-02 2.90235669e-01 3.56181660e+05]
# FWHM_0: 1.024531911210575
# p1_0: [9.55925496e+04 1.86298841e-02 2.90235669e-01 3.56181660e+05]
# Processing FWHM of poisson noised fit case 15, diameter 10.0 mm.
# [-1.05968686e+05  1.07172360e-01 -1.51153690e+00  4.55693853e+05]
# FWHM_0: 5.335725259146405
# p1_0: [-1.05968686e+05  1.07172360e-01 -1.51153690e+00  4.55693853e+05]
# Processing FWHM of poisson noised fit case 16, diameter 1.0 mm.
# [-1.13979541e+04  5.83172680e-02 -2.23359615e-01  2.56239507e+05]
# FWHM_0: 0.7884594422519763
# p1_0: [-1.13979541e+04  5.83172680e-02 -2.23359615e-01  2.56239507e+05]
# Processing FWHM of poisson noised fit case 16, diameter 10.0 mm.
# [-1.64332119e+04  1.62804673e-01 -1.78582691e+00  2.60651612e+05]
# FWHM_0: 6.30396900901521
# p1_0: [-1.64332119e+04  1.62804673e-01 -1.78582691e+00  2.60651612e+05]
# Processing FWHM of poisson noised fit case 17, diameter 1.0 mm.
# [-2.72384012e+04  1.09752901e-02 -2.24868097e-01  2.56502102e+05]
# FWHM_0: 0.7937843826889728
# p1_0: [-2.72384012e+04  1.09752901e-02 -2.24868097e-01  2.56502102e+05]
# Processing FWHM of poisson noised fit case 17, diameter 10.0 mm.
# [3.28323589e+04 1.14381788e-01 1.66322769e+00 2.28791700e+05]
# FWHM_0: 5.871193730246053
# p1_0: [3.28323589e+04 1.14381788e-01 1.66322769e+00 2.28791700e+05]
# Processing FWHM of poisson noised fit case 18, diameter 1.0 mm.
# [-5.38754479e+04  4.74630132e-03 -2.17275569e-01  2.56687695e+05]
# FWHM_0: 0.7669827574922338
# p1_0: [-5.38754479e+04  4.74630132e-03 -2.17275569e-01  2.56687695e+05]
# Processing FWHM of poisson noised fit case 18, diameter 10.0 mm.
# [6.24779171e+04 2.19067386e-01 1.66953639e+00 2.01468752e+05]
# FWHM_0: 5.89346346663604
# p1_0: [6.24779171e+04 2.19067386e-01 1.66953639e+00 2.01468752e+05]
# Processing FWHM of poisson noised fit case 19, diameter 1.0 mm.
# [-2.18184224e+04  6.45620827e-02 -2.02588697e-01  5.16785946e+05]
# FWHM_0: 0.7151381008969047
# p1_0: [-2.18184224e+04  6.45620827e-02 -2.02588697e-01  5.16785946e+05]
# Processing FWHM of poisson noised fit case 19, diameter 10.0 mm.
# [-1.97750186e+04 -1.54955233e-01 -7.65365638e-01  4.79817876e+05]
# FWHM_0: 2.7017407018912984
# p1_0: [-1.97750186e+04 -1.54955233e-01 -7.65365638e-01  4.79817876e+05]
# Processing FWHM of poisson noised fit case 20, diameter 1.0 mm.
# [-5.50296680e+04  2.03783479e-02 -1.93895509e-01  5.17365480e+05]
# FWHM_0: 0.6844511470059677
# p1_0: [-5.50296680e+04  2.03783479e-02 -1.93895509e-01  5.17365480e+05]
# Processing FWHM of poisson noised fit case 20, diameter 10.0 mm.
# [5.48783147e+04 2.44001775e-02 1.02003688e+00 4.27391661e+05]
# FWHM_0: 3.6007301804759275
# p1_0: [5.48783147e+04 2.44001775e-02 1.02003688e+00 4.27391661e+05]
# Processing FWHM of poisson noised fit case 21, diameter 1.0 mm.
# [1.08421813e+05 1.21486789e-02 1.77727462e-01 4.08984334e+05]
# FWHM_0: 0.627377939803791
# p1_0: [1.08421813e+05 1.21486789e-02 1.77727462e-01 4.08984334e+05]
# Processing FWHM of poisson noised fit case 21, diameter 10.0 mm.
# [-1.01648635e+05  1.38930186e-02 -1.03103395e+00  4.84490522e+05]
# FWHM_0: 3.6395498414863305
# p1_0: [-1.01648635e+05  1.38930186e-02 -1.03103395e+00  4.84490522e+05]
# Processing FWHM of poisson noised fit case 22, diameter 1.0 mm.
# [-6.85719178e+03  2.26935274e-01 -1.69064529e-01  1.36904850e+05]
# FWHM_0: 0.5967977876500428
# p1_0: [-6.85719178e+03  2.26935274e-01 -1.69064529e-01  1.36904850e+05]
# Processing FWHM of poisson noised fit case 22, diameter 10.0 mm.
# [-6.94307875e+03 -9.22969747e-01 -1.15014548e+00  1.23038952e+05]
# FWHM_0: 4.060013552213804
# p1_0: [-6.94307875e+03 -9.22969747e-01 -1.15014548e+00  1.23038952e+05]
# Processing FWHM of poisson noised fit case 23, diameter 1.0 mm.
# [-1.54482506e+04  6.57031904e-02 -1.62594543e-01  1.36659131e+05]
# FWHM_0: 0.5739587355821675
# p1_0: [-1.54482506e+04  6.57031904e-02 -1.62594543e-01  1.36659131e+05]
# Processing FWHM of poisson noised fit case 23, diameter 10.0 mm.
# [-1.47095601e+04 -5.94867688e-01 -1.39983080e+00  1.23734629e+05]
# FWHM_0: 4.941402741595784
# p1_0: [-1.47095601e+04 -5.94867688e-01 -1.39983080e+00  1.23734629e+05]
# Processing FWHM of poisson noised fit case 24, diameter 1.0 mm.
# [-3.07326200e+04  3.28225719e-02 -1.56205801e-01  1.37011060e+05]
# FWHM_0: 0.551406476864651
# p1_0: [-3.07326200e+04  3.28225719e-02 -1.56205801e-01  1.37011060e+05]
# Processing FWHM of poisson noised fit case 24, diameter 10.0 mm.
# [-3.14516237e+04 -3.17102193e-01 -1.53156846e+00  1.24753826e+05]
# FWHM_0: 5.4064366581591266
# p1_0: [-3.14516237e+04 -3.17102193e-01 -1.53156846e+00  1.24753826e+05]
# Processing FWHM of poisson noised fit case 25, diameter 1.0 mm.
# [4.14700777e+03 1.46789945e-01 1.00923219e-01 7.41841433e+04]
# FWHM_0: 0.35625896282752745
# p1_0: [4.14700777e+03 1.46789945e-01 1.00923219e-01 7.41841433e+04]
# Processing FWHM of poisson noised fit case 25, diameter 10.0 mm.
# [-4.10221972e+03  7.48306696e-01 -1.73930347e+00  7.27518395e+04]
# FWHM_0: 6.139741248004848
# p1_0: [-4.10221972e+03  7.48306696e-01 -1.73930347e+00  7.27518395e+04]
# Processing FWHM of poisson noised fit case 26, diameter 1.0 mm.
# [9.29887267e+03 4.03543962e-02 1.34334708e-01 6.91350601e+04]
# FWHM_0: 0.4742015196908459
# p1_0: [9.29887267e+03 4.03543962e-02 1.34334708e-01 6.91350601e+04]
# Processing FWHM of poisson noised fit case 26, diameter 10.0 mm.
# [-9.15271347e+03  5.55387969e-01 -1.69865142e+00  7.31987630e+04]
# FWHM_0: 5.996239508957217
# p1_0: [-9.15271347e+03  5.55387969e-01 -1.69865142e+00  7.31987630e+04]
# Processing FWHM of poisson noised fit case 27, diameter 1.0 mm.
# [1.79289595e+04 2.02198305e-02 1.42577668e-01 6.05952678e+04]
# FWHM_0: 0.5032991675627235
# p1_0: [1.79289595e+04 2.02198305e-02 1.42577668e-01 6.05952678e+04]
# Processing FWHM of poisson noised fit case 27, diameter 10.0 mm.
# [1.80787831e+04 7.92009346e-02 1.67993625e+00 5.55227475e+04]
# FWHM_0: 5.930174970371513
# p1_0: [1.80787831e+04 7.92009346e-02 1.67993625e+00 5.55227475e+04]
# Processing FWHM of poisson noised fit case 28, diameter 1.0 mm.
# [ 2.18223429e+05 -5.91423788e-03  5.39916551e-01  4.70144752e+06]
# FWHM_0: 1.9059054254997887
# p1_0: [ 2.18223429e+05 -5.91423788e-03  5.39916551e-01  4.70144752e+06]
# Processing FWHM of poisson noised fit case 28, diameter 10.0 mm.
# [-1.72806887e+05  6.87649052e-02 -1.25274341e+00  3.75756293e+06]
# FWHM_0: 4.4221842317879725
# p1_0: [-1.72806887e+05  6.87649052e-02 -1.25274341e+00  3.75756293e+06]
# Processing FWHM of poisson noised fit case 29, diameter 1.0 mm.
# [ 4.82349459e+05 -2.37123973e-02  4.88446070e-01  4.42264177e+06]
# FWHM_0: 1.724214625968274
# p1_0: [ 4.82349459e+05 -2.37123973e-02  4.88446070e-01  4.42264177e+06]
# Processing FWHM of poisson noised fit case 29, diameter 10.0 mm.
# [-4.16742754e+05  5.48311555e-02 -1.24028910e+00  3.76825048e+06]
# FWHM_0: 4.378220531501458
# p1_0: [-4.16742754e+05  5.48311555e-02 -1.24028910e+00  3.76825048e+06]
# Processing FWHM of poisson noised fit case 30, diameter 1.0 mm.
# FWHM_0: 2.0975139158034235
# p1_0: [ 1.08773934e+06 -7.14263367e-03  5.94196577e-01  3.88090745e+06]
# Processing FWHM of poisson noised fit case 30, diameter 10.0 mm.
# [8.11558265e+05 7.19278653e-02 1.23469393e+00 2.97774830e+06]
# FWHM_0: 4.3584695891323
# p1_0: [8.11558265e+05 7.19278653e-02 1.23469393e+00 2.97774830e+06]
# Processing FWHM of poisson noised fit case 31, diameter 1.0 mm.
# [-5.52611681e+04  1.17717043e-02 -3.05568175e-01  1.24445494e+06]
# FWHM_0: 1.0786556574109125
# p1_0: [-5.52611681e+04  1.17717043e-02 -3.05568175e-01  1.24445494e+06]
# Processing FWHM of poisson noised fit case 31, diameter 10.0 mm.
# [-7.01603290e+04 -2.86675691e-01 -1.57568202e+00  1.24429601e+06]
# FWHM_0: 5.562157516212028
# p1_0: [-7.01603290e+04 -2.86675691e-01 -1.57568202e+00  1.24429601e+06]
# Processing FWHM of poisson noised fit case 32, diameter 1.0 mm.
# [-1.32302206e+05 -9.45958666e-03 -2.92239788e-01  1.24641025e+06]
# FWHM_0: 1.031606453238943
# p1_0: [-1.32302206e+05 -9.45958666e-03 -2.92239788e-01  1.24641025e+06]
# Processing FWHM of poisson noised fit case 32, diameter 10.0 mm.
# [ 1.49003458e+05 -7.55162208e-02  1.49364643e+00  1.09978427e+06]
# FWHM_0: 5.2725719107426485
# p1_0: [ 1.49003458e+05 -7.55162208e-02  1.49364643e+00  1.09978427e+06]
# Processing FWHM of poisson noised fit case 33, diameter 1.0 mm.
# [2.67522188e+05 1.82277004e-02 2.88588635e-01 9.82751584e+05]
# FWHM_0: 1.0187178826515655
# p1_0: [2.67522188e+05 1.82277004e-02 2.88588635e-01 9.82751584e+05]
# Processing FWHM of poisson noised fit case 33, diameter 10.0 mm.
# [-2.96509092e+05  4.45722799e-02 -1.53419779e+00  1.25855260e+06]
# FWHM_0: 5.4157181995248695
# p1_0: [-2.96509092e+05  4.45722799e-02 -1.53419779e+00  1.25855260e+06]
# Processing FWHM of poisson noised fit case 34, diameter 1.0 mm.
# [2.72116551e+04 4.23773594e-02 2.26942171e-01 6.83669462e+05]
# FWHM_0: 0.8011058649735251
# p1_0: [2.72116551e+04 4.23773594e-02 2.26942171e-01 6.83669462e+05]
# Processing FWHM of poisson noised fit case 34, diameter 10.0 mm.
# [ 4.16499526e+04 -2.41518113e-01  1.73717119e+00  6.76704767e+05]
# FWHM_0: 6.132214287939901
# p1_0: [ 4.16499526e+04 -2.41518113e-01  1.73717119e+00  6.76704767e+05]
# Processing FWHM of poisson noised fit case 35, diameter 1.0 mm.
# [-7.14696726e+04  6.01902866e-03 -2.24050570e-01  7.11579186e+05]
# FWHM_0: 0.7908985116814198
# p1_0: [-7.14696726e+04  6.01902866e-03 -2.24050570e-01  7.11579186e+05]
# Processing FWHM of poisson noised fit case 35, diameter 10.0 mm.
# [ 8.87494939e+04 -1.07768496e-01  1.62769849e+00  6.32227595e+05]
# FWHM_0: 5.745775680345138
# p1_0: [ 8.87494939e+04 -1.07768496e-01  1.62769849e+00  6.32227595e+05]
# Processing FWHM of poisson noised fit case 36, diameter 1.0 mm.
# [-1.47137675e+05  4.03084049e-03 -2.15228755e-01  7.11944532e+05]
# FWHM_0: 0.7597575064280168
# p1_0: [-1.47137675e+05  4.03084049e-03 -2.15228755e-01  7.11944532e+05]
# Processing FWHM of poisson noised fit case 36, diameter 10.0 mm.
# [1.73452435e+05 9.91367862e-02 1.67663818e+00 5.54497584e+05]
# FWHM_0: 5.918532765879903
# p1_0: [1.73452435e+05 9.91367862e-02 1.67663818e+00 5.54497584e+05]
# Processing FWHM of poisson noised fit case 37, diameter 1.0 mm.
# [-3.54936240e+04  1.97214910e-02 -2.61363310e-01  8.50375422e+05]
# FWHM_0: 0.9226124840190593
# p1_0: [-3.54936240e+04  1.97214910e-02 -2.61363310e-01  8.50375422e+05]
# Processing FWHM of poisson noised fit case 37, diameter 10.0 mm.
# [-3.99986213e+04 -1.31643583e-01 -7.69835476e-01  8.13615182e+05]
# FWHM_0: 2.7175192303184494
# p1_0: [-3.99986213e+04 -1.31643583e-01 -7.69835476e-01  8.13615182e+05]
# Processing FWHM of poisson noised fit case 38, diameter 1.0 mm.
# [-8.71384342e+04  4.35134535e-03 -2.09498892e-01  8.50829830e+05]
# FWHM_0: 0.7395310877819882
# p1_0: [-8.71384342e+04  4.35134535e-03 -2.09498892e-01  8.50829830e+05]
# Processing FWHM of poisson noised fit case 38, diameter 10.0 mm.
# [ 9.71789317e+04 -2.99238737e-02  9.65460110e-01  7.19405287e+05]
# FWHM_0: 3.4080741871008087
# p1_0: [ 9.71789317e+04 -2.99238737e-02  9.65460110e-01  7.19405287e+05]
# Processing FWHM of poisson noised fit case 39, diameter 1.0 mm.
# [-1.77579982e+05  5.60916393e-03 -1.83272471e-01  8.51591085e+05]
# FWHM_0: 0.6469518243413274
# p1_0: [-1.77579982e+05  5.60916393e-03 -1.83272471e-01  8.51591085e+05]
# Processing FWHM of poisson noised fit case 39, diameter 10.0 mm.
# [ 1.76719057e+05 -5.99211527e-03  1.03064249e+00  6.44120518e+05]
# FWHM_0: 3.6381679767571606
# p1_0: [ 1.76719057e+05 -5.99211527e-03  1.03064249e+00  6.44120518e+05]
# Processing FWHM of poisson noised fit case 40, diameter 1.0 mm.
# [-6.41913710e+03  3.66657603e-01 -6.41357690e-02  2.26812491e+05]
# FWHM_0: 0.22639926445961076
# p1_0: [-6.41913710e+03  3.66657603e-01 -6.41357690e-02  2.26812491e+05]
# Processing FWHM of poisson noised fit case 40, diameter 10.0 mm.
# [-1.38497211e+04 -1.01622291e+00 -1.07497425e+00  2.11118361e+05]
# FWHM_0: 3.7946591027904093
# p1_0: [-1.38497211e+04 -1.01622291e+00 -1.07497425e+00  2.11118361e+05]
# Processing FWHM of poisson noised fit case 41, diameter 1.0 mm.
# [-2.14220002e+04  6.87477159e-02 -1.73155504e-01  2.26319702e+05]
# FWHM_0: 0.6112389296567249
# p1_0: [-2.14220002e+04  6.87477159e-02 -1.73155504e-01  2.26319702e+05]
# Processing FWHM of poisson noised fit case 41, diameter 10.0 mm.
# [-2.72491342e+04 -7.10812292e-01 -1.36172363e+00  2.12305398e+05]
# FWHM_0: 4.806884424296267
# p1_0: [-2.72491342e+04 -7.10812292e-01 -1.36172363e+00  2.12305398e+05]
# Processing FWHM of poisson noised fit case 42, diameter 1.0 mm.
# [-4.78634040e+04  3.39452169e-02 -1.57803052e-01  2.26820111e+05]
# FWHM_0: 0.5570447733995888
# p1_0: [-4.78634040e+04  3.39452169e-02 -1.57803052e-01  2.26820111e+05]
# Processing FWHM of poisson noised fit case 42, diameter 10.0 mm.
# [ 5.51665023e+04 -3.74904425e-01  1.54913915e+00  1.59227884e+05]
# FWHM_0: 5.4684612009122695
# p1_0: [ 5.51665023e+04 -3.74904425e-01  1.54913915e+00  1.59227884e+05]
# Processing FWHM of poisson noised fit case 43, diameter 1.0 mm.
# [-9.13801297e+03  1.01886850e-01 -1.27438031e-01  1.33221867e+05]
# FWHM_0: 0.44985624965516646
# p1_0: [-9.13801297e+03  1.01886850e-01 -1.27438031e-01  1.33221867e+05]
# Processing FWHM of poisson noised fit case 43, diameter 10.0 mm.
# [-5.56987581e+03 -1.08377172e+00 -4.69463115e-01  1.20900995e+05]
# FWHM_0: 1.6572047967960577
# p1_0: [-5.56987581e+03 -1.08377172e+00 -4.69463115e-01  1.20900995e+05]
# Processing FWHM of poisson noised fit case 44, diameter 1.0 mm.
# [-1.75158751e+04  2.18221496e-02 -1.41623471e-01  1.33376898e+05]
# FWHM_0: 0.4999308529806412
# p1_0: [-1.75158751e+04  2.18221496e-02 -1.41623471e-01  1.33376898e+05]
# Processing FWHM of poisson noised fit case 44, diameter 10.0 mm.
# [-1.56922813e+04 -1.78780583e-01 -1.60181767e+00  1.22700328e+05]
# FWHM_0: 5.654416381600177
# p1_0: [-1.56922813e+04 -1.78780583e-01 -1.60181767e+00  1.22700328e+05]
# Processing FWHM of poisson noised fit case 45, diameter 1.0 mm.
# [3.20825628e+04 1.59835354e-02 1.45663025e-01 1.01408626e+05]
# FWHM_0: 0.5141904781947199
# p1_0: [3.20825628e+04 1.59835354e-02 1.45663025e-01 1.01408626e+05]
# Processing FWHM of poisson noised fit case 45, diameter 10.0 mm.
# [ 2.97193943e+04 -1.93033696e-01  1.62424930e+00  9.38217785e+04]
# FWHM_0: 5.733600044789248
# p1_0: [ 2.97193943e+04 -1.93033696e-01  1.62424930e+00  9.38217785e+04]
# Processing FWHM of poisson noised fit case 46, diameter 1.0 mm.
# [-3.79157032e+05  3.22014267e-02 -5.38157454e-01  8.28331803e+06]
# FWHM_0: 1.89969581352967
# p1_0: [-3.79157032e+05  3.22014267e-02 -5.38157454e-01  8.28331803e+06]
# Processing FWHM of poisson noised fit case 46, diameter 10.0 mm.
# [-3.32581343e+05  6.17852381e-03 -1.18700652e+00  6.46798741e+06]
# FWHM_0: 4.190133031444251
# p1_0: [-3.32581343e+05  6.17852381e-03 -1.18700652e+00  6.46798741e+06]
# Processing FWHM of poisson noised fit case 47, diameter 1.0 mm.
# [-8.44237331e+05  5.13732558e-02 -4.60233455e-01  8.28352203e+06]
# FWHM_0: 1.6246240961548752
# p1_0: [-8.44237331e+05  5.13732558e-02 -4.60233455e-01  8.28352203e+06]
# Processing FWHM of poisson noised fit case 47, diameter 10.0 mm.
# [-7.58238486e+05  2.05378326e-02 -1.23570220e+00  6.48970186e+06]
# FWHM_0: 4.362028775525645
# p1_0: [-7.58238486e+05  2.05378326e-02 -1.23570220e+00  6.48970186e+06]
# Processing FWHM of poisson noised fit case 48, diameter 1.0 mm.
# [-1.77119319e+06  1.58517823e-02 -5.41991989e-01  8.33716600e+06]
# FWHM_0: 1.9132317229102036
# p1_0: [-1.77119319e+06  1.58517823e-02 -5.41991989e-01  8.33716600e+06]
# Processing FWHM of poisson noised fit case 48, diameter 10.0 mm.
# [-1.42598251e+06  5.28654816e-02 -1.21947408e+00  6.51999280e+06]
# FWHM_0: 4.304743496562343
# p1_0: [-1.42598251e+06  5.28654816e-02 -1.21947408e+00  6.51999280e+06]
# Processing FWHM of poisson noised fit case 49, diameter 1.0 mm.
# [-9.73264108e+04  8.30530131e-02 -3.17124784e-01  2.12916673e+06]
# FWHM_0: 1.1194504881088492
# p1_0: [-9.73264108e+04  8.30530131e-02 -3.17124784e-01  2.12916673e+06]
# Processing FWHM of poisson noised fit case 49, diameter 10.0 mm.
# [-1.14072579e+05 -5.32863153e-01 -1.48193233e+00  2.12060095e+06]
# FWHM_0: 5.231221126849842
# p1_0: [-1.14072579e+05 -5.32863153e-01 -1.48193233e+00  2.12060095e+06]
# Processing FWHM of poisson noised fit case 50, diameter 1.0 mm.
# [-2.30271655e+05  2.02320798e-02 -3.04566696e-01  2.13367491e+06]
# FWHM_0: 1.0751204384898578
# p1_0: [-2.30271655e+05  2.02320798e-02 -3.04566696e-01  2.13367491e+06]
# Processing FWHM of poisson noised fit case 50, diameter 10.0 mm.
# [ 2.48881685e+05 -2.03469232e-01  1.46183243e+00  1.87907479e+06]
# FWHM_0: 5.160268490760106
# p1_0: [ 2.48881685e+05 -2.03469232e-01  1.46183243e+00  1.87907479e+06]
# Processing FWHM of poisson noised fit case 51, diameter 1.0 mm.
# [4.63486190e+05 3.33358404e-02 2.92424563e-01 1.67672417e+06]
# FWHM_0: 1.0322587090411772
# p1_0: [4.63486190e+05 3.33358404e-02 2.92424563e-01 1.67672417e+06]
# Processing FWHM of poisson noised fit case 51, diameter 10.0 mm.
# [-5.04044042e+05 -3.37933324e-02 -1.53031306e+00  2.14492283e+06]
# FWHM_0: 5.402005088613447
# p1_0: [-5.04044042e+05 -3.37933324e-02 -1.53031306e+00  2.14492283e+06]
# Processing FWHM of poisson noised fit case 52, diameter 1.0 mm.
# [-5.20675117e+04  7.24659381e-02 -2.65792157e-01  1.22489474e+06]
# FWHM_0: 0.9382463140815815
# p1_0: [-5.20675117e+04  7.24659381e-02 -2.65792157e-01  1.22489474e+06]
# Processing FWHM of poisson noised fit case 52, diameter 10.0 mm.
# [-6.66911377e+04 -3.23673515e-01 -1.48201131e+00  1.22836156e+06]
# FWHM_0: 5.231499928906087
# p1_0: [-6.66911377e+04 -3.23673515e-01 -1.48201131e+00  1.22836156e+06]
# Processing FWHM of poisson noised fit case 53, diameter 1.0 mm.
# [-1.27326684e+05  2.39043288e-02 -2.44886387e-01  1.22698669e+06]
# FWHM_0: 0.8644489455791944
# p1_0: [-1.27326684e+05  2.39043288e-02 -2.44886387e-01  1.22698669e+06]
# Processing FWHM of poisson noised fit case 53, diameter 10.0 mm.
# [-1.48034407e+05 -1.36753984e-01 -1.52967860e+00  1.23304439e+06]
# FWHM_0: 5.399765447987602
# p1_0: [-1.48034407e+05 -1.36753984e-01 -1.52967860e+00  1.23304439e+06]
# Processing FWHM of poisson noised fit case 54, diameter 1.0 mm.
# [-2.56519088e+05  1.32638359e-02 -2.23478207e-01  1.22733678e+06]
# FWHM_0: 0.7888780710444138
# p1_0: [-2.56519088e+05  1.32638359e-02 -2.23478207e-01  1.22733678e+06]
# Processing FWHM of poisson noised fit case 54, diameter 10.0 mm.
# [2.97200086e+05 6.75396904e-02 1.65565639e+00 9.48621539e+05]
# FWHM_0: 5.844467068690432
# p1_0: [2.97200086e+05 6.75396904e-02 1.65565639e+00 9.48621539e+05]

# %% [markdown]
# ## Compute mean and standard deviation for each case

# %%
noised = df_poisson.reset_index(drop=True)
print(noised.head())
print(noised.tail())
# Out:
#    case  diameter    FWHM_0    FWHM_1    FWHM_2    FWHM_3    FWHM_4    FWHM_5  \
# 0     1       1.0  0.571810  0.565516  0.428025  0.537788  0.632817  0.438605
# 1     1      10.0  3.366162  3.284247  3.810458  4.082767  3.691404  3.996689
# 2     2       1.0  0.651304  0.607743  0.616646  0.631956  0.606559  0.575512
# 3     2      10.0  3.786124  3.775863  3.738349  4.096626  4.025057  4.080892
# 4     3       1.0  0.612419  0.597489  0.613170  0.622198  0.610427  0.604797
#
#      FWHM_6    FWHM_7  ...  FWHM_991  FWHM_992  FWHM_993  FWHM_994  FWHM_995  \
# 0  0.517445  0.539639  ...  0.542376  0.516231  0.645348  0.513100  0.579981
# 1  3.255794  3.160987  ...  4.084755  3.308898  3.082206  2.928364  3.357099
# 2  0.669513  0.638186  ...  0.613620  0.636878  0.626405  0.642238  0.596698
# 3  3.686547  3.821923  ...  4.116784  3.762726  3.605041  3.673192  4.056667
# 4  0.612096  0.611559  ...  0.599610  0.602816  0.599511  0.586363  0.585727
#
#    FWHM_996  FWHM_997  FWHM_998  FWHM_999  FWHM_orig
# 0  0.535167  0.507042  0.529653  0.400275   0.561688
# 1  3.954632  3.699939  2.447809  3.917140   3.570739
# 2  0.633530  0.630319  0.576600  0.626442   0.620737
# 3  3.832385  3.815590  3.750625  3.769829   3.809578
# 4  0.592898  0.615606  0.621609  0.620332   0.606902
#
# [5 rows x 1003 columns]
#      case  diameter    FWHM_0    FWHM_1    FWHM_2    FWHM_3    FWHM_4  \
# 103    52      10.0  5.185130  5.491140  5.457543  5.222774  5.320519
# 104    53       1.0  0.860551  0.844621  0.854653  0.868896  0.860513
# 105    53      10.0  5.357437  5.289440  5.319684  5.439444  5.234418
# 106    54       1.0  0.774878  0.786181  0.788347  0.796705  0.800516
# 107    54      10.0  5.756501  5.799633  5.969385  5.809354  5.794619
#
#        FWHM_5    FWHM_6    FWHM_7  ...  FWHM_991  FWHM_992  FWHM_993  \
# 103  4.911541  5.128242  5.426180  ...  5.431025  5.145989  5.147500
# 104  0.837276  0.866791  0.857230  ...  0.800946  0.860387  0.873287
# 105  5.284322  5.322310  5.248050  ...  5.281244  5.294855  5.393234
# 106  0.786400  0.792310  0.779310  ...  0.794876  0.784582  0.803794
# 107  5.901250  5.797419  5.761801  ...  5.853072  5.811239  5.823674
#
#      FWHM_994  FWHM_995  FWHM_996  FWHM_997  FWHM_998  FWHM_999  FWHM_orig
# 103  5.709802  4.991491  5.206774  5.303128  5.224104  5.154842   5.231500
# 104  0.870167  0.862374  0.860849  0.851405  0.851962  0.852893   0.864449
# 105  5.465759  5.390360  5.172142  5.445798  5.353137  5.467833   5.399765
# 106  0.780997  0.792118  0.794501  0.790068  0.799420  0.781587   0.788878
# 107  5.863032  5.789195  5.861675  5.841950  5.864474  5.847530   5.844467
#
# [5 rows x 1003 columns]

# %%
# take only the FWHM columns
cols_fwhm = [c for c in noised.columns if "FWHM" in c]
# make a new df, with same index
df_fwhm = noised[cols_fwhm]
# compute mean and std
mean = df_fwhm.mean(axis = 1)
std = df_fwhm.std(axis = 1)
df_m_and_std = pd.DataFrame([mean, std], ['mean', 'std']).T
# join the two dataframes back
df_infos = noised[['case', 'diameter']]
df_fwhms = df_infos.join(df_m_and_std, on=df_infos.index)

# add properties to the df
df_props = pd.read_csv('/Users/hkromer/02_PhD/02_Data/09.NeutronEmittingSpot/01.FindingGoodParameters/df_properties_with_FWHM_penumbra.csv', index_col=0)
df_props['diameter'] = df_props['radius'] * 20 # convert to mm

df_out = pd.merge(df_fwhms, df_props,  how='left', left_on=['case','diameter'], right_on = ['case','diameter'])
df_out.drop(columns=['FWHM_LSF', 'FWHM_c'], inplace=True)
df_out.head()
# Out:
#    case  diameter      mean       std   D_W  D_det  W_det  dist_det  radius
# 0     1       1.0  0.562289  0.063633  0.10    0.5    0.2        30    0.05
# 1     1      10.0  3.605779  0.451650  0.10    0.5    0.2        30    0.50
# 2     2       1.0  0.619594  0.027277  0.25    0.5    0.2        30    0.05
# 3     2      10.0  3.806225  0.173232  0.25    0.5    0.2        30    0.50
# 4     3       1.0  0.606922  0.012474  0.50    0.5    0.2        30    0.05

# %% [markdown]
# ## How much different is the FWHM for different detector depths
#
# - tungsten depth is fixed to 0.5 cm
# - 1 and 10 mm diameter source definition from MCNP6

# %%
import matplotlib
import copy
# from matplotlib.ticker import AutoMinorLocator
# %matplotlib inline
import os
os.environ["PATH"] += os.pathsep + '/usr/local/texlive/2018/bin/x86_64-darwin'
plt.rc('text', usetex=True)
plt.rc('font', weight='bold')
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Arial'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.tt'] = 'Arial'
matplotlib.rcParams['mathtext.cal'] = 'Arial'
matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']


diam = 10

# fix tungsten thickness to 0.5 cm
df = df_out[ (df_out['diameter'] == diam) & (df_out['D_W'] == 0.5)]

lst_D_det = df['D_det'].unique()
lst_D_W = df['D_W'].unique()
lst_W_det = df['W_det'].unique()
lst_dist_det = df['dist_det'].unique()



markers = ['o', 'v', '<', 's', 'D', '>'] 
colors = ['darkblue', 'darkred', 'darkorange', 'darkgreen']



# plot
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(1, 1, 1)
fs = 20
markersize = 8
outputfolder = '/Users/hkromer/polybox/Thesis/Chapters/DetailedNeutronGeneratorCharacterization/Figures/emitting_spot_size_finding_parameters/'
figname = f'fwhm_vs_detector_depth_{diam}'
handles = []  # legend handles to change color of legend

# markers are different detector width and heights
# colors are different detector distances
for W_det, marker in zip(lst_W_det, markers):
    for dist_det, color in zip(lst_dist_det, colors):
        this_data = df[ (df['W_det'] == W_det) & (df['dist_det'] == dist_det)]
        X = this_data['D_det'].values
        Y = this_data['mean'].values
        Y_err = this_data['std'].values
        ax1.errorbar(X, Y, yerr=Y_err, marker='.', color=color, capsize=5, markersize=0)   
        _, = ax1.plot(X, Y, marker=marker, markersize=markersize, label=dist_det, color=color, alpha=0.8)
        handles.append(copy.copy(_))

plt.ylabel(r'\textbf{Estimated FWHM [mm]}', fontsize=fs)
plt.xlabel(r'\textbf{Detector depth [cm]}', fontsize=fs)

# minor ticks x
minor_locator = AutoMinorLocator(2)
ax1.xaxis.set_minor_locator(minor_locator)
# minor ticks y
minor_locator = AutoMinorLocator(2)
ax1.yaxis.set_minor_locator(minor_locator)
ax1.tick_params('x', colors='black', labelsize=fs-2)
ax1.tick_params('y', colors='black', labelsize=fs-2)

ax1.grid(b=True, which='major', linestyle='-')
ax1.grid(b=True, which='minor', linestyle='--')



plt.yticks(np.arange(3.5,7.5,0.5))
plt.xticks(np.arange(0.5,3.5,0.5))
plt.xlim(0.375, 3.125)
plt.ylim(3.5,6.5)
# legend
# legend for the tungsten thickness
my_handles, my_labels = ax1.get_legend_handles_labels()
# my_handles = [my_handles[1], my_handles[0], my_handles[3], my_handles[2]]
# my_labels = [my_labels[1], my_labels[0], my_labels[3], my_labels[2]]
l1 = plt.legend(my_handles[:3], my_labels[:3], loc=(0.65, 0.34), markerscale=0, fontsize=12, handlelength=1)
l1.set_title(r"Detector-source distance [cm]", prop = {'size': 12})
# change color of legend
for h in handles:
    h.set_color("black")

l2 = plt.legend(handles[0::4], list(lst_W_det), loc=(0.30, 0.393), handlelength=0, fontsize=12)
l2.set_title(r"Detector width and height [cm]", prop = {'size': 12})
plt.gca().add_artist(l1)

plt.tight_layout()
plt.savefig(f'{outputfolder}/{figname}.pdf')
plt.show()

# %% [markdown]
# ### 1 mm diameter

# %%
import matplotlib
import copy
# from matplotlib.ticker import AutoMinorLocator
# %matplotlib inline
import os
os.environ["PATH"] += os.pathsep + '/usr/local/texlive/2018/bin/x86_64-darwin'
plt.rc('text', usetex=True)
plt.rc('font', weight='bold')
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Arial'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.tt'] = 'Arial'
matplotlib.rcParams['mathtext.cal'] = 'Arial'
matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']



diam = 1

# fix tungsten thickness to 0.5 cm
df = df_out[ (df_out['diameter'] == diam) & (df_out['D_W'] == 0.5)]

lst_D_det = df['D_det'].unique()
lst_D_W = df['D_W'].unique()
lst_W_det = df['W_det'].unique()
lst_dist_det = df['dist_det'].unique()



markers = ['o', 'v', '<', 's', 'D', '>'] 
colors = ['darkblue', 'darkred', 'darkorange', 'darkgreen']



# plot
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(1, 1, 1)
fs = 20
markersize = 8
outputfolder = '/Users/hkromer/polybox/Thesis/Chapters/DetailedNeutronGeneratorCharacterization/Figures/emitting_spot_size_finding_parameters/'
figname = f'fwhm_vs_detector_depth_{diam}'
handles = []  # legend handles to change color of legend

# markers are different detector width and heights
# colors are different detector distances
for W_det, marker in zip(lst_W_det, markers):
    for dist_det, color in zip(lst_dist_det, colors):
        this_data = df[ (df['W_det'] == W_det) & (df['dist_det'] == dist_det)]
        X = this_data['D_det'].values
        Y = this_data['mean'].values
        _, = ax1.plot(X, Y, marker=marker, markersize=markersize, label=dist_det, color=color, alpha=0.8)
        ax1.errorbar(X, Y, yerr=Y_err, marker='.', color=color, capsize=5, markersize=0)   
        handles.append(copy.copy(_))

plt.ylabel(r'\textbf{Estimated FWHM [mm]}', fontsize=fs)
plt.xlabel(r'\textbf{Detector depth [cm]}', fontsize=fs)


# minor ticks x
minor_locator = AutoMinorLocator(2)
ax1.xaxis.set_minor_locator(minor_locator)
# minor ticks y
minor_locator = AutoMinorLocator(2)
ax1.yaxis.set_minor_locator(minor_locator)
ax1.tick_params('x', colors='black', labelsize=fs-2)
ax1.tick_params('y', colors='black', labelsize=fs-2)


ax1.tick_params('x', colors='black', labelsize=fs-2)
ax1.tick_params('y', colors='black', labelsize=fs-2)

ax1.grid(b=True, which='major', linestyle='-')
ax1.grid(b=True, which='minor', linestyle='--')



plt.yticks(np.arange(0,3,0.5))
plt.xticks(np.arange(0.5,3.5,0.5))
plt.xlim(0.375, 3.125)
plt.ylim(0,2.5)
# legend
# legend for the tungsten thickness
my_handles, my_labels = ax1.get_legend_handles_labels()
# my_handles = [my_handles[1], my_handles[0], my_handles[3], my_handles[2]]
# my_labels = [my_labels[1], my_labels[0], my_labels[3], my_labels[2]]
l1 = plt.legend(my_handles[:3], my_labels[:3], loc=(0.65, 0.49), markerscale=0, fontsize=12, handlelength=1)
l1.set_title(r"Detector-source distance [cm]", prop = {'size': 12})
# change color of legend
for h in handles:
    h.set_color("black")

l2 = plt.legend(handles[0::4], list(lst_W_det), loc=(0.30, 0.542), handlelength=0, fontsize=12)
l2.set_title(r"Detector width and height [cm]", prop = {'size': 12})
plt.gca().add_artist(l1)

plt.tight_layout()
plt.savefig(f'{outputfolder}/{figname}.pdf')
plt.show()

# %% [markdown]
# - Error are given by the standard deviation of the 1000 fitted ESFs (assuming a poisson distribution)
# - The results conclude that there is negligible influence of the depth of the detector on the ESF seen by the detector
# - However, a deeper detector means that there will
