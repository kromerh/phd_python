# %% [markdown]
# # Measurement 2020-02-03 Neutron Output vs Beam Power
#
# Files in /Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-02-03.NeutronOutputVSBeamPower

# %%
import numpy as np
import pandas as pd
import pymysql
import sqlalchemy as sql
import matplotlib.pyplot as plt
import matplotlib.dates as md
import seaborn as sns
sns.set()
import getopt
import sys
import datetime
from scipy.interpolate import interp1d
from NGDataObject import NGDataObject
from scipy.optimize import curve_fit
from scipy import optimize

#*******************************
# CONSTANTS
#*******************************
# connection to database
CREDENTIALS_FILE = '/Users/hkromer/02_PhD/01.github/dash_NG/credentials.pw'
DB = "NG_twofast_DB" # name of the database
HOST = "twofast-RPi3-0"  # database host

# LOOKUP TABLES
LUT_PRESSURE_ION_SOURCE = "/Users/hkromer/02_PhD/01.github/phd/01_neutron_generator_contol/LUT_pressure_ion_source.txt"

# %%
def load_data_for_day_CSV(DAY, PATH):
    data_dose = pd.read_csv(f'{PATH}/{DAY}_dose.csv', index_col=0)
    data_hv = pd.read_csv(f'{PATH}/{DAY}_hv.csv', index_col=0)
    data_pressure = pd.read_csv(f'{PATH}/{DAY}_pressure.csv', index_col=0)
    data_microwave_power_full = pd.read_csv(f'{PATH}/{DAY}_microwave_power.csv', index_col=0)
    data_microwave_frequency_full = pd.read_csv(f'{PATH}/{DAY}_microwave_frequency.csv', index_col=0)

    for df in [data_dose, data_hv, data_pressure, data_microwave_power_full, data_microwave_frequency_full]:
        df.index = pd.to_datetime(df.index)
        
        
    return data_dose, data_hv, data_pressure, data_microwave_power_full, data_microwave_frequency_full

# %%
def resample_30_seconds(df, cols, range_start, range_end):
    """
    Takes the a grouped df (grouped by day) and resamples the columns cols in 10s
    OUTPUT:
        - dataframe
    """

    d = {}

    s = pd.date_range(start=range_start, end=range_end, freq='10S')
    df_out = pd.DataFrame(pd.Series(s, name='time')).set_index('time')
    for col in cols:
        d[col] = df[col].resample('10S').mean()

    this_d = pd.DataFrame(d)

    df_out = df_out.merge(this_d, left_on=df_out.index, right_on=this_d.index, how='outer')
    df_out = df_out.set_index('key_0')
    df_out.index.name ='time'    
    
    return df_out

# %%
DAY = "2020-02-03"
PATH = '/Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-02-03.NeutronOutputVSBeamPower/'

# %%
data_dose, data_hv, data_pressure, data_microwave_power_full, data_microwave_frequency_full = load_data_for_day_CSV(DAY, PATH)

# %%
time_start = f"{DAY} 08:29:00"
time_end = f"{DAY} 11:00:00"


data_dose = data_dose.loc[time_start:time_end, :]
data_hv = data_hv.loc[time_start:time_end, :]
data_pressure = data_pressure.loc[time_start:time_end, :]
data_microwave_power_full = data_microwave_power_full.loc[time_start:time_end, :]
data_microwave_frequency_full = data_microwave_frequency_full.loc[time_start:time_end, :]

# %% [markdown]
# ## Resample data

# %%
def resample_30_seconds(df, cols, range_start, range_end):
    """
    Takes the a grouped df (grouped by day) and resamples the columns cols in 10s
    OUTPUT:
        - dataframe
    """

    d = {}

    s = pd.date_range(start=range_start, end=range_end, freq='10S')
    df_out = pd.DataFrame(pd.Series(s, name='time')).set_index('time')
    for col in cols:
        d[col] = df[col].resample('10S').mean()

    this_d = pd.DataFrame(d)

    df_out = df_out.merge(this_d, left_on=df_out.index, right_on=this_d.index, how='outer')
    df_out = df_out.set_index('key_0')
    df_out.index.name ='time'    
    
    return df_out

# current resampled in 30s blocks
data_rs_hv = resample_30_seconds(data_hv, ['HV_current', 'HV_voltage'], time_start, time_end)
# pressure resampled in 30s blocks
data_rs_dose = resample_30_seconds(data_dose, ['dose_corrected'], time_start, time_end)


data_rs = pd.merge(data_rs_hv, data_rs_dose, left_index=True, right_index=True, how='outer')
data_rs.head()
# Out:
#                      HV_current  HV_voltage  dose_corrected
# time
# 2020-02-03 08:29:00     0.59616    50.23528             0.0
# 2020-02-03 08:29:10     0.59440    50.17646             0.0
# 2020-02-03 08:29:20     0.59440    50.26469             0.0
# 2020-02-03 08:29:30     0.59440    50.20587             0.0
# 2020-02-03 08:29:40     0.59440    50.20587             0.0

# %% [markdown]
# ### Find different levels in the high voltage

# %%
data_hv['time_delta_minutes'] = data_hv.index
data_hv['time_delta_minutes'] = data_hv['time_delta_minutes'].apply(lambda x: (x - data_hv.index[0]).seconds/60)

# %%
times = pd.read_excel('/Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-02-03.NeutronOutputVSBeamPower/2020-02-03.NeutronOutputVSBeamPower.xlsx', 'Sheet2', header=None)
times.columns = ['t0', 't1']

for col in times.columns:    
    new_col = [f"{DAY} {f}" for f in times[col].astype(str)]  
    times[col] = pd.to_datetime(new_col) 

times['t0'] = times['t0'] + pd.Timedelta('10S')
times['t1'] = times['t1'] - pd.Timedelta('10S')
times['tdiff'] = (times['t1'] - times['t0']).dt.seconds
times = times.loc[~(times['tdiff'] > 800) & ~(times['tdiff'] < 10)]

# %%
HV_m = data_hv[['HV_voltage', 'HV_current', 'time_delta_minutes']]
def get_average_hv_current(row, HV_m):
    t0 = row['t0']
    t1 = row['t1']
    
    hv = HV_m.loc[t0:t1, ['HV_voltage', 'HV_current']]
#     plt.hist(hv['HV_voltage'], bins=20, density=True)
#     plt.show()
#     print(t0)

    m = np.mean(hv)
    m.index = [f"{s}_m" for s in m.index]
    std = np.std(hv)
    std.index = [f"{s}_std" for s in std.index]
    
#     print(pd.concat([m, std]))
    return pd.concat([m, std])

def get_average_dose(row, data_dose):
    t0 = row['t0']
    t1 = row['t1']
    
    dose = data_dose.loc[t0:t1, ['dose_corrected']]
#     plt.hist(hv['HV_voltage'], bins=20, density=True)
#     plt.show()
#     print(t0)

    m = np.mean(dose)
    m.index = [f"{s}_m" for s in m.index]
    std = np.std(dose)
    std.index = [f"{s}_std" for s in std.index]
    
#     print(pd.concat([m, std]))
    return pd.concat([m, std])
a = times.apply(lambda x: get_average_hv_current(x, HV_m), axis=1)
times = times.reset_index(drop=True)
data = pd.merge(times, a, left_index=True, right_index=True)

a = times.apply(lambda x: get_average_dose(x, data_dose), axis=1)
times = times.reset_index(drop=True)
data = pd.merge(data, a, left_index=True, right_index=True)
data.head()
# Out:
#                    t0                  t1  tdiff  HV_voltage_m  HV_current_m  \
# 0 2020-02-03 08:29:10 2020-02-03 08:31:50    160     50.908239      0.481293
# 1 2020-02-03 08:32:10 2020-02-03 08:36:50    280     55.000000      0.604682
# 2 2020-02-03 08:37:10 2020-02-03 08:37:50     40     55.970590      0.606720
# 3 2020-02-03 08:38:10 2020-02-03 08:43:50    340     59.983517      0.549742
# 4 2020-02-03 08:44:10 2020-02-03 08:45:50    100     61.461676      0.621822
#
#    HV_voltage_std  HV_current_std  dose_corrected_m  dose_corrected_std
# 0        1.647150        0.209602          0.015074            0.076118
# 1        0.000000        0.004184          0.000000            0.000000
# 2        1.837000        0.006541          0.000000            0.000000
# 3        0.067647        0.168308         30.795268           19.558481
# 4        2.234345        0.008078         52.933022           17.594489

# %% [markdown]
# ### Correct the current for the leakage current

# %%
data_leak = pd.read_csv('/Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-02-03.NeutronOutputVSBeamPower/2020-02-03_LEAKGE_CURRENT_LUT.csv', index_col=0)
data_leak.reset_index(drop=True, inplace=True)
data_leak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HV_current      36 non-null     float64
#  1   HV_voltage      36 non-null     float64
#  2   dose_corrected  36 non-null     float64
# dtypes: float64(3)
# memory usage: 1.0 KB

# %%
data_leak = data_leak.sort_values(by = 'HV_voltage').reset_index(drop=True)
data_leak.head()
# Out:
#    HV_current  HV_voltage  dose_corrected
# 0    0.064865    50.58820        0.399449
# 1    0.073513    55.00000        0.399449
# 2    0.079568    58.88235        2.796144
# 3    0.082162    59.97059        5.192839
# 4    0.091243    63.68750        5.192839

# %%
dupli = data_leak[data_leak.duplicated(subset=['HV_voltage'], keep='first')]
dupli2 = dupli[dupli.duplicated(subset=['HV_voltage'], keep=False)]
data_leak = data_leak.drop_duplicates(subset=['HV_voltage'], keep=False)

# %%
# first duplicates to be replaced
dupli_1 = pd.concat([dupli,dupli2]).drop_duplicates(keep=False)
data_leak = pd.concat([data_leak, dupli_1]).sort_values(by='HV_voltage')

# %%
# more than one entries in duplicate voltage: do averaging
m = pd.DataFrame(np.mean(dupli2)).T
data_leak = pd.concat([data_leak, m]).sort_values(by='HV_voltage').reset_index(drop=True)
data_leak.to_csv('/Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-02-03.NeutronOutputVSBeamPower/2020-02-03_LEAKGE_CURRENT_LUT.csv')

# %%
# interpolate
X = data_leak['HV_voltage'].values.astype(np.float64)
Y = data_leak['HV_current'].values.astype(np.float64)
interp_leak = interp1d(X, Y, fill_value='extrapolate')
x = np.linspace(40, 160, 1000, endpoint=True)
plt.plot(x, interp_leak(x), color='red')
plt.scatter(data_leak['HV_voltage'], data_leak['HV_current'])
plt.xlabel('High voltage [kV]')
plt.ylabel('Leakage current [mA]')
plt.show()

# %%
# real target current without leakage current
# 3          0.467549  28.045209  1.009576e+01
# 4          0.536017  32.944506  1.296471e+00
# 5          0.538865  35.026218  6.494805e-14
# 6          0.545760  37.694007  1.148815e+00
# 7          0.543904  38.073266  3.432562e-02
# 8          0.544256  39.135307  1.373133e+00
# 9          0.545267  40.812445  1.589302e-01
# 10         0.547053  43.764280  1.613067e-01
# 11         0.546698  43.735830  1.456187e-01
# 12         0.547821  44.605878  1.457904e+00
# 13         0.552084  46.998184  9.003612e-02
# 14         0.550476  48.093246  1.558371e+00
# 15         0.549102  49.494639  5.418962e-02
# 16         0.559282  53.131826  2.108734e-01
# 17         0.504903  47.965825  1.519234e+01
# 18         0.570806  56.938377  8.558590e-01
# 19         0.571599  57.159928  1.897380e-01
# 20         0.572995  58.863961  2.298937e+00
# 21         0.576048  60.485030  2.474641e-01
# 22         0.578019  62.483805  2.183909e+00
# 24         0.582611  64.819704  2.218093e+00
# 25         0.586660  67.435576  6.824424e-01
# 26         0.583833  69.061930  2.532981e+00
# 27         0.583226  69.683466  3.454881e+00
# 28         0.436528  52.338055  2.773946e+01
# 29         0.579775  71.725795  2.526688e+00
# 30         0.578607  72.163964  2.592994e+00
# 31         0.425407  53.116100  2.974396e+01
# 32         0.587938  75.537202  3.830597e+00
# 33         0.596591  77.211185  6.995213e+00
# 34         0.592054  77.073409  5.266308e-01
# 35         0.594196  79.510554  3.159848e+00
# 36         0.593844  80.287751  1.164932e+00
# 37         0.590120  81.546383  6.758497e+00

# %% [markdown]
# ### Dose to neutron output

# %%
data_mcnp_LUT = pd.read_csv("/Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-03-01.MCNP_2e8nps/LUT_dose_output.csv", index_col=0) # output per 100 muSv/hr
# take 100 kV
interp_dose = interp1d(data_mcnp_LUT.index, data_mcnp_LUT['E'].values, fill_value='extrapolate')
x = np.linspace(70, 140, 100, endpoint=True)
plt.plot(x, interp_dose(x), color='red')
plt.scatter(data_mcnp_LUT.index, data_mcnp_LUT['E'])
plt.xlabel('High voltage [kV]')
plt.ylabel('output per 100 muSv/h')
plt.show()

dose_to_output = data_mcnp_LUT.loc[100, 'E']


dose_to_output = dose_to_output / 100 # per 1 muSv/h
dose_to_output # output per 1 muSv/hr
# Out:
# 34719.54196076212

# %%
data['neutron_output'] = data['dose_corrected_m'].values * (interp_dose(data['HV_voltage_m'].values) / 100)
data['neutron_output_std'] = data['dose_corrected_std'].values * (interp_dose(data['HV_voltage_m'].values) / 100)

data['ratio'] = (data['neutron_output'] / data['power']) * 1e-5
data['ratio_std'] = np.sqrt( ( ( ( data['neutron_output_std'] ) / data['power'])**2 ) + ( ( ( data['neutron_output'] ) / ( (data['power'])**2 ) * data['power_std'] )**2 ) ) * 1e-5
cols = ['HV_voltage_m', 'power', 'power_std', 'neutron_output', 'neutron_output_std', 'ratio', 'ratio_std']
data[cols]
# Out:
#     HV_voltage_m      power     power_std  neutron_output  neutron_output_std  \
# 0      50.908239  21.167662  1.069244e+01    5.137185e+02        2.594151e+03
# 8    1.753473   0.204684
# 9    2.151169   0.046953
# 10   2.323884   0.159605
# 11   2.557744   0.056493
# 12   2.598090   0.178994
# 13   3.052309   0.040791
# 14   3.147949   0.240244
# 15   3.548255   0.027939
# 16   3.891608   0.143650
# 17   4.025668   1.761781
# 18   4.449548   0.219432
# 19   4.519503   0.026649
# 20   4.796367   0.449915
# 21   5.089149   0.046681
# 22   5.224156   0.360936
# 24   6.205312   0.217631
# 25   6.341668   0.327630
# 26   6.568836   0.244581
# 27   4.696427   2.215455
# 28   9.353883   4.974768
# 29   7.064179   0.251072
# 30   4.921373   2.488597
# 31  10.179741   5.722336
# 32   7.495181   0.380898
# 33   7.291719   0.662168
# 34   7.796652   0.346427
# 35   7.824547   0.314339
# 36   8.191590   0.309528
# 37   7.462200   0.621813

# %%
data.head()
# Out:
#                    t0                  t1  tdiff  HV_voltage_m  HV_current_m  \
# 0 2020-02-03 08:29:10 2020-02-03 08:31:50    160     50.908239      0.481293
# 1 2020-02-03 08:32:10 2020-02-03 08:36:50    280     55.000000      0.604682
# 2 2020-02-03 08:37:10 2020-02-03 08:37:50     40     55.970590      0.606720
# 3 2020-02-03 08:38:10 2020-02-03 08:43:50    340     59.983517      0.549742
# 4 2020-02-03 08:44:10 2020-02-03 08:45:50    100     61.461676      0.621822
#
#    HV_voltage_std  HV_current_std  dose_corrected_m  dose_corrected_std  \
# 0        1.647150        0.209602          0.015074            0.076118
# 1        0.000000        0.004184          0.000000            0.000000
# 2        1.837000        0.006541          0.000000            0.000000
# 3        0.067647        0.168308         30.795268           19.558481
# 4        2.234345        0.008078         52.933022           17.594489
#
#    HV_current_real      power  power_std  neutron_output  neutron_output_std  \
# 0         0.415800  21.167662  10.692442    5.137185e+02         2594.151474
# 1         0.531169  29.214292   0.230143    0.000000e+00            0.000000
# 2         0.531693  29.759169   1.043080    0.000000e+00            0.000000
# 3         0.467549  28.045209  10.095760    1.053261e+06       668940.018900
# 4         0.536017  32.944506   1.296471    1.811463e+06       602114.939952
#
#       ratio  ratio_std
# 0  0.000243   0.001232
# 1  0.000000   0.000000
# 2  0.000000   0.000000
# 3  0.375558   0.274172
# 4  0.549853   0.184043

# %% [markdown]
# ### Clean some datapoints with very large errors --> low stability with many breakdowns

# %%
idx_to_remove = data[cols].loc[(data['power_std'] > 9) | (data['ratio_std'] > 2)].index
data_cleaned = data.drop(idx_to_remove)

# %%
X = data_cleaned['power'].values # W
X_err = data_cleaned['power_std'].values # W
Y = data_cleaned['ratio'].values # 1e5 n/s/W
Y_err = data_cleaned['ratio_std'].values # 1e5 n/s/W
plt.scatter(X, Y, color='darkblue')
plt.errorbar(X, Y, yerr=Y_err, xerr=X_err, ls='none')
plt.ylabel('Output per beam power [1e5 n/s/W]')
plt.xlabel('Beam power [W]')
plt.show()

# %%
data_cleaned.to_csv('/Users/hkromer/02_PhD/02_Data/13.new_chamber/2020-02-03.NeutronOutputVSBeamPower/data_cleaned.csv', index=False)

# %% [markdown]
# # Comparison with rotating target and robert data
#
# - Roberts datafiles in: /Users/hkromer/02_PhD/02_Data/07.neutron_output/data_from_Robert/

# %%
from matplotlib.ticker import AutoMinorLocator
sns.reset_orig()
import os, matplotlib
os.environ["PATH"] += os.pathsep + '/usr/local/texlive/2018/bin/x86_64-darwin'
plt.rc('text', usetex=True)
plt.rc('font', weight='bold')
from matplotlib.ticker import AutoMinorLocator
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Arial'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.tt'] = 'Arial'
matplotlib.rcParams['mathtext.cal'] = 'Arial'
matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']

# %% [markdown]
# ### Roberts data

# %%
# output (neutrons/s)
output_data_file = '/Users/hkromer/02_PhD/02_Data/07.neutron_output/data_from_Robert/output_neutronsPerSecond.csv'
output_data = pd.read_csv(output_data_file)
# output per unit power (neutrons/s/W)
output_vs_power_file = '/Users/hkromer/02_PhD/02_Data/07.neutron_output/data_from_Robert/output_vs_power_neutronsPerSecondPerWatt.csv'
output_vs_power = pd.read_csv(output_vs_power_file)
#hv=60:5:125; % high voltage values in kV
hv = np.arange(60, 130, 5)
power = output_data / output_vs_power # beam power in W
neutron_yield_file = '/Users/hkromer/02_PhD/02_Data/07.neutron_output/data_from_Robert/output_vs_power.csv'
neutron_yield = pd.read_csv(neutron_yield_file, delimiter='\t')
neutron_yield = neutron_yield.multiply(1e5)

# %%
output_vs_power.head()
# Out:
#     3perc   6perc   9perc  12perc
# 0   47600   70800   80700   59700
# 1   59900   89300  101000   76800
# 2   74000  106000  107000  117000
# 3   84700  130000  112000  131000
# 4  105000  135000  123000  121000

# %%
cols_ra = power.columns.tolist()
markers = ['o', 's', "^", "v"]
for col, marker in zip(cols_ra, markers):
    plt.scatter(power.loc[:,col], output_vs_power.loc[:,col]/1e5, marker=marker, label=col)

plt.xlim(0, 70)
plt.legend(loc='best')

# %% [markdown]
# ### Rotating target data

# %%
# datafile from COMSOL
path_to_data = '/Users/hkromer/polybox/Thesis/Chapters/RotatingIonBeamTarget/Figures/neutron_yield_vs_beam_power/data/'
output_folder = '/Users/hkromer/polybox/Thesis/Chapters/RotatingIonBeamTarget/Figures/neutron_yield_vs_beam_power/'

df = pd.read_csv(f'{path_to_data}/df.csv', index_col=0)

# %%
OUTPUT_FOLDER = '/Users/hkromer/polybox/Thesis/Chapters/FurtherNeutronGeneratorUpgrades/Figures/Output_vs_beampower/'
FIGNAME = 'Output_vs_beampower'

# %%
annotation = pd.DataFrame(
                        {'HV': ['-80', '-100', '-120', '-140'],
                        'power': [43.764280, 57.159928, 69.061930, 81.546383],
                        'ratio': [2.323884, 4.519503, 6.568836, 7.462200]}
                        )

# %%
# -------------------------------------------------------------------
# plot measured output (n/s/W) vs beam power
# -------------------------------------------------------------------

fig = plt.figure(figsize=(10, 7))
fs = 22
ms = 10 # marker size
# axis 1
ax1 = fig.add_subplot(1, 1, 1)
# Hide the right and top spines
# ax1.spines['right'].set_visible(False)
# ax1.spines['top'].set_visible(False)

# take only reasonable data
df1 = df[ ((df.index >= "2017-12-21 14:03") & (df.index <= "2017-12-21 15:06"))]
df2 = df[((df.index >= "2017-12-21 15:15") & (df.index <= "2017-12-21 16:14"))]
# print(df2.head())

ax1.plot(df1['beam_power'], (df1['output'] / df1['beam_power']) / 1e5,  'v',color="darkorange", markersize=ms, label='-80 kV \n (rotating target)', alpha=0.65, markeredgewidth=1.5, markeredgecolor='darkorange')
ax1.plot(df2['beam_power'], (df2['output'] / df2['beam_power']) / 1e5,  'o',color="darkblue", markersize=ms, label = '-90 kV \n (rotating target)', alpha=0.65, markeredgewidth=1.5, markeredgecolor='darkblue')
plt.ylim(0,9)
plt.xlim(10,95)
ax1.xaxis.set_ticks(np.arange(20,100,10))
# minor ticks x
minor_locator = AutoMinorLocator(2)
ax1.xaxis.set_minor_locator(minor_locator)
# minor ticks y
minor_locator = AutoMinorLocator(2)
ax1.yaxis.set_minor_locator(minor_locator)
# tick font size
ax1.tick_params('x', colors='black', labelsize=fs-2)	
ax1.tick_params('y', colors='black', labelsize=fs-2)	
ax1.set_ylabel(r'\textbf{Neutron yield [10$^5$ s$^{-1}$ W$^{-1}$]}', fontsize=fs)
ax1.set_xlabel(r'\textbf{Beam power [W]}', fontsize=fs, labelpad=2)

# ax1.text(70, 1e7, r"Data averaged over 1 min"  "\n"  r"ca 250 rpm" "\n" r"0.4 - 1.0 mA (DF 1 - 60 \% )",  bbox={'facecolor':'white', 'alpha':0.9, 'pad':10})

col = '12perc'
marker = 's'
plot_adams, = ax1.plot(power.loc[:,col], output_vs_power.loc[:,col]/1e5, color='darkred', linestyle='None', markeredgecolor='darkred', label="Adams et al. (2015) \n (non-rotating target)", markersize=ms, alpha=0.65, markeredgewidth=1.5, marker=marker)


ax1.grid(b=True, which='major', linestyle='-')#, color='gray')
ax1.grid(b=True, which='minor', linestyle='--')#, color='gray')
handles, labels = ax1.get_legend_handles_labels()
leg1 = plt.legend(handles=[handles[2], handles[0], handles[1]], labels=[labels[2], labels[0], labels[1]], bbox_to_anchor=(1.0005,1.02),loc="upper left",  fontsize=fs-4)
leg1.set_title(r"Gen. I neutron generator", prop = {'size': fs-4})

# leg2 = ax1.legend([plot_adams],['Adams et al. (2015)'], loc=(0.60, 0.008), fontsize=fs-4)
# Manually add the first legend back
plot_new_chamber, = ax1.plot(X, Y, 'd', color='darkgreen', markersize=ms, alpha=0.85, markeredgewidth=1.5, markeredgecolor='darkgreen')
leg3 = ax1.legend([plot_new_chamber],['Gen. II neutron generator \n -50 to -140 kV'], bbox_to_anchor=(1.0005,0.6),loc="upper left", fontsize=fs-4)

for ii in range(len(annotation)):
    x = annotation.iloc[ii].loc['power']
    y = annotation.iloc[ii].loc['ratio']
    txt = annotation.iloc[ii].loc['HV']
    if ii < 2:
        ax1.text(x-3.25,y+1.45,f"{txt} kV", fontsize=18, fontweight='bold', color='darkgreen')
    #     ax1.arrow(x,y+2.5,0,-1, color='red', length_includes_head=True, head_width=0.6) 
        ax1.annotate(s=None, fontsize=18, xy=(x,y), xytext=(x,y+1),
                arrowprops=dict(arrowstyle='simple, head_length=0.6,head_width=0.6,tail_width=0.2', color='black', alpha=0.6), va='center', color="darkgreen", alpha=0.6)
    else:
        ax1.text(x-3,y-1.5,f"{txt} kV", fontsize=18, fontweight='bold', color='darkgreen')
    #     ax1.arrow(x,y+2.5,0,-1, color='red', length_includes_head=True, head_width=0.6) 
        ax1.annotate(s=None, fontsize=18, xy=(x,y), xytext=(x,y-1),
                arrowprops=dict(arrowstyle='simple, head_length=0.6,head_width=0.6,tail_width=0.2', color='black', alpha=0.6), va='center', color="darkgreen", alpha=0.6)
   

        
ax1.add_artist(leg1)
# ax1.add_artist(leg2)
plt.tight_layout()
plt.savefig(f'{OUTPUT_FOLDER}/{FIGNAME}.pdf', dpi=900)
plt.show()

# %%
data_cleaned[cols]
# Out:
#     HV_voltage_m      power     power_std  neutron_output  neutron_output_std  \
# 1      55.000000  29.214292  2.301429e-01    0.000000e+00        0.000000e+00
# 2      55.970590  29.759169  1.043080e+00    0.000000e+00        0.000000e+00
# 4      61.461676  32.944506  1.296471e+00    1.811463e+06        6.021149e+05
# 5      65.000000  35.026218  6.494805e-14    4.635503e+06        4.410351e+05
# 6      69.066980  37.694007  1.148815e+00    5.747498e+06        7.232926e+05
# 7      70.000000  38.073266  3.432562e-02    6.384536e+06        2.027396e+05
# 8      71.906065  39.135307  1.373133e+00    6.862269e+06        7.639964e+05
# 9      74.848500  40.812445  1.589302e-01    8.779445e+06        1.885507e+05
# 10     80.000000  43.764280  1.613067e-01    1.017031e+07        6.974931e+05
# 11     80.000000  43.735830  1.456187e-01    1.118650e+07        2.442524e+05
# 12     81.424240  44.605878  1.457904e+00    1.158901e+07        7.028495e+05
# 13     85.128671  46.998184  9.003612e-02    1.434530e+07        1.897288e+05
# 14     87.366655  48.093246  1.558371e+00    1.513951e+07        1.046096e+06
# 15     90.137382  49.494639  5.418962e-02    1.756196e+07        1.369381e+05
# 16     95.000000  53.131826  2.108734e-01    2.067682e+07        7.588139e+05
# 18     99.750816  56.938377  8.558590e-01    2.533501e+07        1.189961e+06
# 19    100.000000  57.159928  1.897380e-01    2.583345e+07        1.258918e+05
# 20    102.730392  58.863961  2.298937e+00    2.823331e+07        2.407917e+06
# 21    105.000000  60.485030  2.474641e-01    3.078173e+07        2.527066e+05
# 22    108.100000  62.483805  2.183909e+00    3.264251e+07        1.945389e+06
# 24    111.257286  64.819704  2.218093e+00    4.022265e+07        3.091057e+05
# 25    114.948408  67.435576  6.824424e-01    4.276540e+07        2.166590e+06
# 26    118.290566  69.061930  2.532981e+00    4.536565e+07        2.909565e+05
# 29    123.713208  71.725795  2.526688e+00    5.066839e+07        2.390215e+05
# 32    128.478107  75.537202  3.830597e+00    5.661650e+07        1.872232e+05
# 33    129.420658  77.211185  6.995213e+00    5.630022e+07        3.495806e+05
# 34    130.179711  77.073409  5.266308e-01    6.009145e+07        2.638272e+06
# 35    133.812087  79.510554  3.159848e+00    6.221341e+07        3.656535e+05
# 36    135.200000  80.287751  1.164932e+00    6.576844e+07        2.294617e+06
# 37    138.186167  81.546383  6.758497e+00    6.085155e+07        5.257812e+05
#
#        ratio  ratio_std
# 1   0.000000   0.000000
# 2   0.000000   0.000000
# 4   0.549853   0.184043
# 5   1.323438   0.125916
# 6   1.524778   0.197432
# 7   1.676908   0.053271
# 8   1.753473   0.204684
# 9   2.151169   0.046953
# 10  2.323884   0.159605
# 11  2.557744   0.056493
# 12  2.598090   0.178994
# 13  3.052309   0.040791
# 14  3.147949   0.240244
# 15  3.548255   0.027939
# 16  3.891608   0.143650
# 18  4.449548   0.219432
# 19  4.519503   0.026649
# 20  4.796367   0.449915
# 21  5.089149   0.046681
# 22  5.224156   0.360936
# 24  6.205312   0.217631
# 25  6.341668   0.327630
# 26  6.568836   0.244581
# 29  7.064179   0.251072
# 32  7.495181   0.380898
# 33  7.291719   0.662168
# 34  7.796652   0.346427
# 35  7.824547   0.314339
# 36  8.191590   0.309528
# 37  7.462200   0.621813

# %% [markdown]
# ## Plot for snsf

# %%
# datafile from COMSOL
path_to_data = '/Users/hkromer/polybox/Thesis/Chapters/RotatingIonBeamTarget/Figures/neutron_yield_vs_beam_power/data/'
output_folder = '/Users/hkromer/polybox/Thesis/Chapters/RotatingIonBeamTarget/Figures/neutron_yield_vs_beam_power/'

df = pd.read_csv(f'{path_to_data}/df.csv', index_col=0)

# %% [markdown]
# # Plot time series of neutron output

# %%
# correct leakage
data_rs['HV_current_real'] = data_rs['HV_current'] - interp_leak(data_rs['HV_voltage'].values)
data_rs['time_min'] = data_rs.reset_index().index / 6

# neutron output
data_rs['neutron_output'] = data_rs['dose_corrected'].values * (interp_dose(data_rs['HV_voltage'].values) / 100)


OUTPUT_FOLDER = '/Users/hkromer/polybox/Thesis/Chapters/FurtherNeutronGeneratorUpgrades/Figures/Neutron_output_over_time/'
FIGNAME = 'Neutron_output_over_time'

fig = plt.figure(figsize=(10,6))
fs = 20

plt.plot(data_rs['time_min'].values, data_rs['HV_voltage'].values, label='Voltage [-kV]', color='darkred')
plt.plot(data_rs['time_min'].values, data_rs['HV_current_real'].values * 100, label='Current [0.01 mA]', color='darkorange')
ax = plt.gca()

_ = plt.xlabel(r'\textbf{Measurement time [min]}',fontsize=fs)
_ = ax.set_ylabel(r'\textbf{High voltage power supply}', color='black',fontsize=fs)
_ = plt.legend(loc=(0.01, 0.85), fontsize=fs-4, framealpha=1)
# minor ticks x
minor_locator = AutoMinorLocator(2)
ax.xaxis.set_minor_locator(minor_locator)
# minor ticks y
minor_locator = AutoMinorLocator(2)
ax.yaxis.set_minor_locator(minor_locator)
# tick font size
ax.tick_params('x', colors='black', labelsize=fs-2)	
ax.tick_params('y', colors='black', labelsize=fs-2)	
# grid
ax.grid(b=True, which='major', linestyle='-')#, color='gray')
ax.grid(b=True, which='minor', linestyle='--')#, color='gray')


ax2 = ax.twinx()
# Turns off grid on the secondary (right) Axis.
ax2.grid(False)

ax2.set_ylabel(r"\textbf{Neutron yield [10$^{7}$ s$^{-1}$]}", color='darkblue',fontsize=fs)

ax2.tick_params(axis='y', labelcolor='darkblue', labelsize=fs-2)
plt.plot(data_rs['time_min'].values, data_rs['neutron_output'].values*1e-7, label='Neutron yield', color='darkblue')


_ = ax2.legend(loc="lower right", fontsize=fs-4, framealpha=1)
ax.set_ylim(0, 150)
ax.set_xlim(0, 150)
ax2.set_ylim(0, 7.5)
# ax2.set_yticks(np.arange(0, 2.4+0.2, 0.4))
plt.tight_layout()
plt.savefig(f'{OUTPUT_FOLDER}/{FIGNAME}.pdf')
plt.show()

# %%
plt.plot(data_rs['time_min'], data_rs['dose_corrected'])
plt.show()

# %% [markdown]
# # Neutron yield vs beam power

# %%
FIGNAME = 'total_output_vs_beam_power'
# -------------------------------------------------------------------
# plot measured output (n/s/W) vs beam power
# -------------------------------------------------------------------

fig = plt.figure(figsize=(10, 5))
fs = 22
ms = 10 # marker size
# axis 1
ax1 = fig.add_subplot(1, 1, 1)
# Hide the right and top spines
# ax1.spines['right'].set_visible(False)
# ax1.spines['top'].set_visible(False)

# take only reasonable data
df1 = df[ ((df.index >= "2017-12-21 14:03") & (df.index <= "2017-12-21 15:06"))]
df2 = df[((df.index >= "2017-12-21 15:15") & (df.index <= "2017-12-21 16:14"))]
# print(df2.head())

X = df1['beam_power'].values
Y = X * (df1['output'] / df1['beam_power']) / 1e7
ax1.plot(X, Y,  'v',color="darkorange", markersize=ms, label='-80 kV \n (rotating target)', alpha=0.65, markeredgewidth=1.5, markeredgecolor='darkorange')

X = df2['beam_power'].values
Y = X * (df2['output'] / df2['beam_power']) / 1e7
ax1.plot(X, Y,  'o',color="darkblue", markersize=ms, label = '-90 kV \n (rotating target)', alpha=0.65, markeredgewidth=1.5, markeredgecolor='darkblue')

ax1.xaxis.set_ticks(np.arange(20,100,10))
# minor ticks x
minor_locator = AutoMinorLocator(2)
ax1.xaxis.set_minor_locator(minor_locator)
# minor ticks y
minor_locator = AutoMinorLocator(2)
ax1.yaxis.set_minor_locator(minor_locator)
# tick font size
ax1.tick_params('x', colors='black', labelsize=fs-2)	
ax1.tick_params('y', colors='black', labelsize=fs-2)	
ax1.set_ylabel(r'\textbf{Neutron yield [10$^7$ s$^{-1}$]}', fontsize=fs)
ax1.set_xlabel(r'\textbf{Beam power [W]}', fontsize=fs, labelpad=2)

# ax1.text(70, 1e7, r"Data averaged over 1 min"  "\n"  r"ca 250 rpm" "\n" r"0.4 - 1.0 mA (DF 1 - 60 \% )",  bbox={'facecolor':'white', 'alpha':0.9, 'pad':10})
col = '12perc'
marker = 's'
X = power.loc[:,col]
Y = X * output_vs_power.loc[:,col] / 1e7
plot_adams, = ax1.plot(X, Y, color='darkred', linestyle='None', markeredgecolor='darkred', markersize=ms,label="Adams et al. (2015) \n (non-rotating target)", alpha=0.65, markeredgewidth=1.5, marker=marker)

ax1.grid(b=True, which='major', linestyle='-')#, color='gray')
ax1.grid(b=True, which='minor', linestyle='--')#, color='gray')
handles, labels = ax1.get_legend_handles_labels()
leg1 = plt.legend(handles=[handles[2], handles[0], handles[1]], labels=[labels[2], labels[0], labels[1]], bbox_to_anchor=(1.0005,1.02),loc="upper left",  fontsize=fs-4)
leg1.set_title(r"Gen. I neutron generator", prop = {'size': fs-4})




# Manually add the first legend back
X = data_cleaned['power'].values # W
Y = X * data_cleaned['ratio'].values / 100 # 1e5 n/s/W
plot_new_chamber, = ax1.plot(X, Y, 'd', color='darkgreen', markersize=ms, alpha=0.85, markeredgewidth=1.5, markeredgecolor='darkgreen')
leg3 = ax1.legend([plot_new_chamber],['Gen. II neutron generator \n -50 to -140 kV'], loc=(0.37, 0.84), fontsize=fs-4)

x = 43.764280 # power
hv = -80 # hv
y = 1.2 # ratio
ax1.text(x-3,y+2,f"{hv} kV", fontsize=18, fontweight='bold', color='darkgreen')
#     ax1.arrow(x,y+2.5,0,-1, color='red', length_includes_head=True, head_width=0.6) 
ax1.annotate(s=None, fontsize=18, xy=(x,y), xytext=(x,y+1.9),
        arrowprops=dict(arrowstyle='simple, head_length=0.6,head_width=0.6,tail_width=0.2', color='black', alpha=0.6), va='center', color="darkgreen", alpha=0.6)

hv = -100 # hv
x = 57.159928 # power
y = 2.6 # ratio
ax1.text(x-3.5,y+2,f"{hv} kV", fontsize=18, fontweight='bold', color='darkgreen')
#     ax1.arrow(x,y+2.5,0,-1, color='red', length_includes_head=True, head_width=0.6) 
ax1.annotate(s=None, fontsize=18, xy=(x,y), xytext=(x,y+1.9),
        arrowprops=dict(arrowstyle='simple, head_length=0.6,head_width=0.6,tail_width=0.2', color='black', alpha=0.6), va='center', color="darkgreen", alpha=0.6)

hv = -120 # hv
x = 69.06193 # power
y = 4.5 # ratio
ax1.text(x-3,y-2.0,f"{hv} kV", fontsize=18, fontweight='bold', color='darkgreen')
#     ax1.arrow(x,y+2.5,0,-1, color='red', length_includes_head=True, head_width=0.6) 
ax1.annotate(s=None, fontsize=18, xy=(x,y), xytext=(x,y-1.6),
        arrowprops=dict(arrowstyle='simple, head_length=0.6,head_width=0.6,tail_width=0.2', color='black', alpha=0.6), va='center', color="darkgreen", alpha=0.6)

hv = -140 # hv
x = 81.546383 # power
y = 6.1 # ratio
ax1.text(x-3.2,y-2,f"{hv} kV", fontsize=18, fontweight='bold', color='darkgreen')
#     ax1.arrow(x,y+2.5,0,-1, color='red', length_includes_head=True, head_width=0.6) 
ax1.annotate(s=None, fontsize=18, xy=(x,y), xytext=(x,y-1.5),
        arrowprops=dict(arrowstyle='simple, head_length=0.6,head_width=0.6,tail_width=0.2', color='black', alpha=0.6), va='center', color="darkgreen", alpha=0.6)



        
ax1.add_artist(leg1)
ax1.add_artist(leg2)
plt.ylim(0,8)
plt.xlim(10,95)
plt.tight_layout()
plt.savefig(f'{OUTPUT_FOLDER}/{FIGNAME}.pdf', dpi=900)
plt.show()

# %%
data_cleaned[cols]
